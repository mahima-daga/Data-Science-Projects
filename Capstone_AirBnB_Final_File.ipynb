# %% [markdown]
# # Host Optimal Price Predictions

# %% [markdown]
# ## Problem Statement
#
# Business problem statement
# One challenge that every hosts face is determining the optimal nightly rent price. In many areas, renters aka. hosts are presented with a good selection of listings and can filter by criteria like price, number of bedrooms, room type, and more. The amount a host can charge is ultimately tied to market prices.
# Although there are general guidance which hosts should follow for pricing, there are no easy way to access methods to determine the optimal price to rent out a space.
# There are other models available on the market where one method could be to find a few listings that are similar to the place that will be up for rent, average the listed prices and set our price to this calculated average price. But the market is dynamic, so we would want to update the price frequently and this method can become tedious.
# To identify the growth of the business using a public dataset from Airbnb.,, Analyzing and building the model on how it will perform based on the current business situation and to build a optimal pricing system for the hosts who would opt when they post their properties for rent at the best price.
# Our approach of analysis will include Exploratory Data Analysis (EDA) done on the public dataset we obtained, which may involve in data cleansing, visualization for further analysis of each variable or attribute.
# Moving further, we plan to develop a supervised learning model based on regression to predict the price based on the historic data of the rental price, service charge with the aid of various regression methods or algorithms.
#       In summary, we are going to create a model that helps in predicting the optimal prices with a public dataset available.

# %%
# importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=[15,10]
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Data Dictionary

# %%
pd.set_option('display.max_colwidth',None)
data_dict=pd.read_excel('Data type dictionary.xlsx')
data_dict
# Out:
#                           Features Data type  \
# 0                               id   integer
# 1                             name      text
# 2                          host_id   integer
# 3                        host_name      text
# 4                       host_since      date
# 5                host_is_superhost  boolean
# 6           host_identity_verified  boolean
# 7                 instant_bookable   boolean
# 8                     accommodates   integer
# 9                        amenities    object
# 10                           State    object
# 11             neighbourhood_group    object
# 12                   neighbourhood    object
# 13                        latitude     float
# 14                       longitude     float
# 15                   property_type    object
# 16                       room_type    object
# 17                       bathrooms     float
# 18                        bedrooms     float
# 19                            beds     float
# 20                           price    object
# 21                  minimum_nights   integer
# 22                  maximum_nights   integer
# 23               number_of_reviews   integer
# 24                     last_review      date
# 25               reviews_per_month   integer
# 26  calculated_host_listings_count   integer
# 27                availability_365   integer
#
#                                                                                                                                                         Description
# 0                                                                                                                        Airbnb's unique identifier for the listing
# 1                                                                                                                                               Name of the listing
# 2                                                                                                                          Airbnb's unique identifier for the host.
# 3                                                                                                                                                Name of the host.
# 4                                                The date the host was created. For hosts that are Airbnb guests this could be the date they registered as a guest.
# 5                                                                                                                       To check if the host is a superhost or not.
# 6                                                                                                                        To check if the host is identified or not.
# 7   To check whether the guest can automatically book the listing without the host requiring to accept their booking request. An indicator of a commercial listing.
# 8                                                                                                                               The maximum capacity of the listing
# 9                                                                                                                                The amenities provided by the host
# 10                                                                                                                                 State of the host and residence.
# 11                                                                                                                                 Name of the neighbourhood group.
# 12                                                                                                                                       Name of the neighbourhood.
# 13                                                                                    Uses the World Geodetic System (WGS84) projection for latitude and longitude.
# 14                                                                                    Uses the World Geodetic System (WGS84) projection for latitude and longitude.
# 15                                                                                                                     Type of the property as such by their hosts.
# 16                                                                                                            Type of the room as described as such by their hosts.
# 17                                                                                                                           The number of bathrooms in the listing
# 18                                                                                                                            The number of bedrooms in the listing
# 19                                                                                                                                  The number of beds in the room.
# 20                                                                                                                                    daily price in local currency
# 21                                                                                                                    Minimum number of night stay for the listing.
# 22                                                                                                                    Maximum number of night stay for the listing.
# 23                                                                                                                      The number of reviews made for the listing.
# 24                                                                                                                         The date where the last review was made.
# 25                                                                                           The number of reviews the listing has over the lifetime of the listing
# 26                                                                                                          The number of listings the host has made in the region.
# 27                                                                                                 The availability of the listing for 365 days posted by the host.

# %%
df_original=pd.read_csv('airbnb.csv')

# %%
df=pd.read_csv('airbnb.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158249 entries, 0 to 158248
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              158249 non-null  int64
#  1   name                            158231 non-null  object
#  2   host_id                         158249 non-null  int64
#  3   host_name                       158220 non-null  object
#  4   host_since                      158220 non-null  object
#  5   host_is_superhost               158220 non-null  object
#  6   host_identity_verified          158220 non-null  object
#  7   instant_bookable                158249 non-null  object
#  8   accommodates                    158249 non-null  int64
#  9   amenities                       158249 non-null  object
#  10  State                           158249 non-null  object
#  11  neighbourhood_group             158249 non-null  object
#  12  neighbourhood                   158249 non-null  object
#  13  latitude                        158249 non-null  float64
#  14  longitude                       158249 non-null  float64
#  15  property_type                   158249 non-null  object
#  16  room_type                       158249 non-null  object
#  17  bathrooms                       158065 non-null  float64
#  18  bedrooms                        141614 non-null  float64
#  19  beds                            156965 non-null  float64
#  20  price                           158249 non-null  int64
#  21  minimum_nights                  158249 non-null  int64
#  22  maximum_nights                  158249 non-null  int64
#  23  number_of_reviews               158249 non-null  int64
#  24  last_review                     121694 non-null  object
#  25  reviews_per_month               121694 non-null  float64
#  26  calculated_host_listings_count  158249 non-null  int64
#  27  availability_365                158249 non-null  int64
# dtypes: float64(6), int64(9), object(13)
# memory usage: 33.8+ MB

# %%
pd.set_option('display.max_columns',30)
df.head()
# Out:
#      id                                                name  host_id  \
# 0   109  Amazing bright elegant condo park front *UPGRADED*      521
# 1  2708  Beautiful Furnish Mirrored Mini-Suite w/ Fireplace     3008
# 2  2732                               Zen Life at the Beach     3041
# 3  2864              * Beautiful Master Suite/Jacuzzi Tub/*     3207
# 4  5728     Tiny Home in Artistic Oasis near Venice and LAX     9171
#
#         host_name  host_since host_is_superhost host_identity_verified  \
# 0           Paolo  27-06-2008                 f                      t
# 1           Chas.  16-09-2008                 t                      t
# 2  Yoga Priestess  17-09-2008                 f                      t
# 3       Bernadine  25-09-2008                 f                      t
# 4           Sanni  05-03-2009                 t                      t
#
#   instant_bookable  accommodates  \
# 0                f             6
# 1                t             1
# 2                f             1
# 3                t             2
# 4                f             2
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               amenities  \
# 0                                                                                                                                                                                                                                                                                                                                    ["Elevator", "Cable TV", "Air conditioning", "Carbon monoxide alarm", "Indoor fireplace", "Hangers", "Kitchen", "Hair dryer", "Fire extinguisher", "Heating", "Free parking on premises", "Pool", "Laptop-friendly workspace", "Gym", "Washer", "First aid kit", "Smoke alarm", "Iron", "Wifi", "TV", "Hot tub", "Essentials", "Shampoo", "Dryer"]
# 1  ["Host greets you", "Elevator", "Air conditioning", "Carbon monoxide alarm", "Indoor fireplace", "Hangers", "Kitchen", "Hair dryer", "Garden or backyard", "Fire extinguisher", "Heating", "Free parking on premises", "Luggage dropoff allowed", "Single level home", "Laptop-friendly workspace", "Gym", "Washer", "Dishes and silverware", "Refrigerator", "First aid kit", "Smoke alarm", "Patio or balcony", "Free street parking", "Iron", "Coffee maker", "Wifi", "Hot tub", "Hot water", "Essentials", "Shampoo", "Bed linens", "Microwave", "Oven", "Extra pillows and blankets", "Breakfast", "Stove", "Dryer", "Dishwasher", "Cooking basics", "Long term stays allowed"]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                             ["Cooking basics", "Host greets you", "Smoke alarm", "Patio or balcony", "Refrigerator", "Microwave", "Oven", "Dishes and silverware", "Wifi", "Dryer", "Kitchen", "Hangers", "Washer", "Hair dryer", "Essentials", "Heating", "Shampoo"]
# 3                                                                                                                                                                                                                                                                                                           ["Host greets you", "Air conditioning", "Carbon monoxide alarm", "Hangers", "Hair dryer", "Heating", "Free parking on premises", "Laptop-friendly workspace", "Washer", "Refrigerator", "Smoke alarm", "Free street parking", "Iron", "Wifi", "TV", "Hot water", "Essentials", "Bed linens", "Microwave", "Extra pillows and blankets", "Dryer", "Long term stays allowed"]
# 4                                                                                                                                                                                                                                                                                                                               ["Lock on bedroom door", "Fire extinguisher", "Carbon monoxide alarm", "Hangers", "Hair dryer", "Garden or backyard", "Heating", "Private entrance", "Laptop-friendly workspace", "Washer", "Smoke alarm", "Patio or balcony", "Free street parking", "Iron", "Coffee maker", "Wifi", "TV", "Hot water", "Essentials", "Shampoo", "Microwave", "Dryer"]
#
#         State neighbourhood_group neighbourhood  latitude  longitude  \
# 0  California         Los Angeles   Culver City  33.98209 -118.38494
# 1  California         Los Angeles     Hollywood  34.09768 -118.34602
# 2  California         Los Angeles  Santa Monica  34.00475 -118.48127
# 3  California         Los Angeles    Bellflower  33.87619 -118.11397
# 4  California         Los Angeles       Del Rey  33.98750 -118.43200
#
#                 property_type        room_type  bathrooms  bedrooms  beds  \
# 0          Entire condominium  Entire home/apt        2.0       2.0   3.0
# 1   Private room in apartment     Private room        1.5       1.0   1.0
# 2   Private room in apartment     Private room        1.0       1.0   1.0
# 3            Entire apartment  Entire home/apt        1.0       1.0   1.0
# 4  Private room in tiny house     Private room        1.0       1.0   1.0
#
#    price  minimum_nights  maximum_nights  number_of_reviews last_review  \
# 0    115              30             730                  2  15-05-2016
# 1     71              30             366                 27  06-10-2020
# 2    155               1             180                 21  27-12-2019
# 3     50              30             730                  0         NaN
# 4     60              30            1125                310  29-04-2020
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.02                               1               216
# 1               0.35                               2               360
# 2               0.18                               2               337
# 3                NaN                               1                 0
# 4               2.25                               5               337

# %%
# Describing the Numerical Columns
df.describe().T
# Out:
#                                    count          mean           std  \
# id                              158249.0  2.687799e+07  1.391386e+07
# host_id                         158249.0  9.960864e+07  1.045460e+08
# accommodates                    158249.0  3.857617e+00  2.644270e+00
# latitude                        158249.0  3.470195e+01  6.938362e+00
# longitude                       158249.0 -1.067489e+02  2.796584e+01
# bathrooms                       158065.0  1.437611e+00  8.781675e-01
# bedrooms                        141614.0  1.638313e+00  1.061445e+00
# beds                            156965.0  2.088950e+00  1.790110e+00
# price                           158249.0  2.043707e+02  5.002285e+02
# minimum_nights                  158249.0  6.459666e+02  2.513793e+05
# maximum_nights                  158249.0  1.565310e+04  5.410484e+06
# number_of_reviews               158249.0  1.123548e+02  2.780842e+02
# reviews_per_month               121694.0  1.364488e+00  1.638515e+00
# calculated_host_listings_count  158249.0  1.887050e+01  4.888697e+01
# availability_365                158249.0  1.777522e+02  1.391774e+02
#
#                                       min           25%           50%  \
# id                              109.00000  1.580795e+07  2.820817e+07
# host_id                         470.00000  1.483732e+07  5.467153e+07
# accommodates                      0.00000  2.000000e+00  3.000000e+00
# latitude                         18.92857  3.283720e+01  3.612252e+01
# longitude                      -159.72213 -1.219366e+02 -1.171594e+02
# bathrooms                         0.00000  1.000000e+00  1.000000e+00
# bedrooms                          1.00000  1.000000e+00  1.000000e+00
# beds                              0.00000  1.000000e+00  2.000000e+00
# price                             0.00000  7.500000e+01  1.200000e+02
# minimum_nights                    1.00000  2.000000e+00  3.000000e+00
# maximum_nights                    0.00000  3.000000e+01  3.650000e+02
# number_of_reviews                 0.00000  1.000000e+00  1.200000e+01
# reviews_per_month                 0.01000  2.200000e-01  7.500000e-01
# calculated_host_listings_count    1.00000  1.000000e+00  2.000000e+00
# availability_365                  0.00000  3.600000e+01  1.730000e+02
#
#                                          75%           max
# id                              3.987237e+07  4.694186e+07
# host_id                         1.575800e+08  3.791734e+08
# accommodates                    5.000000e+00  1.600000e+01
# latitude                        4.068729e+01  4.773489e+01
# longitude                      -7.700699e+01 -7.371087e+01
# bathrooms                       2.000000e+00  5.000000e+01
# bedrooms                        2.000000e+00  5.000000e+01
# beds                            3.000000e+00  6.600000e+01
# price                           2.000000e+02  2.500000e+04
# minimum_nights                  3.000000e+01  1.000000e+08
# maximum_nights                  1.125000e+03  2.147484e+09
# number_of_reviews               6.200000e+01  1.825000e+03
# reviews_per_month               1.980000e+00  3.728000e+01
# calculated_host_listings_count  8.000000e+00  3.860000e+02
# availability_365                3.260000e+02  3.650000e+02

# %%
# Describing the Categorical Columns
df.select_dtypes(exclude=np.number).describe().T
# Out:
#                          count  unique  \
# name                    158231  152409
# host_name               158220   22911
# host_since              158220    4231
# host_is_superhost       158220       2
# host_identity_verified  158220       2
# instant_bookable        158249       2
# amenities               158249  136181
# State                   158249       9
# neighbourhood_group     158249      21
# neighbourhood           158249     935
# property_type           158249     132
# room_type               158249       4
# last_review             121694    2369
#
#                                                            top    freq
# name                    A place of your own | 1BR in Las Vegas      73
# host_name                                                  Kia    1541
# host_since                                          16-12-2016    1156
# host_is_superhost                                            f  105684
# host_identity_verified                                       t  126832
# instant_bookable                                             f   88815
# amenities                                                   []     401
# State                                               California   56408
# neighbourhood_group                                Los Angeles   31471
# neighbourhood                                        Las Vegas    9156
# property_type                                 Entire apartment   41637
# room_type                                      Entire home/apt  107847
# last_review                                         25-10-2020    2727

# %%
# Numerical Columns
num_cols=df.select_dtypes(include=np.number).columns
num_cols
# Out:
# Index(['id', 'host_id', 'accommodates', 'latitude', 'longitude', 'bathrooms',
#        'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# categorical Columns
cat_cols=df.select_dtypes(exclude=np.number).columns
cat_cols
# Out:
# Index(['name', 'host_name', 'host_since', 'host_is_superhost',
#        'host_identity_verified', 'instant_bookable', 'amenities', 'State',
#        'neighbourhood_group', 'neighbourhood', 'property_type', 'room_type',
#        'last_review'],
#       dtype='object')

# %%
df.nunique().sort_values(ascending=False)
# Out:
# id                                158234
# name                              152409
# amenities                         136181
# latitude                          100630
# longitude                          98534
# host_id                            86089
# host_name                          22911
# host_since                          4231
# last_review                         2369
# price                               1777
# reviews_per_month                   1159
# neighbourhood                        935
# number_of_reviews                    655
# maximum_nights                       510
# availability_365                     366
# minimum_nights                       158
# property_type                        132
# calculated_host_listings_count       131
# beds                                  43
# bathrooms                             39
# bedrooms                              23
# neighbourhood_group                   21
# accommodates                          17
# State                                  9
# room_type                              4
# host_identity_verified                 2
# instant_bookable                       2
# host_is_superhost                      2
# dtype: int64

# %%
df['State'].unique()
# Out:
# array(['California', 'Illinois', 'Florida', 'Hawaii', 'Nevada',
#        'New York ', 'Tennessee', 'DC', 'Washington'], dtype=object)

# %%
df['neighbourhood'].unique()
# Out:
# array(['Culver City', 'Hollywood', 'Santa Monica', 'Bellflower',
#        'Del Rey', 'Atwater Village', 'Long Beach', 'Venice',
#        'Redondo Beach', 'Mid-Wilshire', 'Harbor Gateway',
#        'Hollywood Hills', 'Torrance', 'Mid-City', 'Valley Village',
#        'East Hollywood', 'Silver Lake', 'Highland Park',
#        'Mount Washington', 'Sawtelle', 'West Los Angeles',
#        'Woodland Hills', 'Los Feliz', 'Mar Vista', 'Malibu', 'Downtown',
#        'Van Nuys', 'Lynwood', 'Glendale', 'Beverly Hills', 'Carthay',
#        'Harvard Heights', 'Glassell Park', 'West Hollywood',
#        'Cheviot Hills', 'Encino', 'Lakewood', 'View Park-Windsor Hills',
#        'North Hills', 'Tujunga', 'Westchester', 'Echo Park',
#        'Sherman Oaks', 'Carson', 'North Hollywood', 'Altadena',
#        'Calabasas', 'Pacific Palisades', 'Hollywood Hills West',
#        'Topanga', 'Valley Glen', 'Fairfax', 'Manhattan Beach',
#        'Unincorporated Santa Monica Mountains', 'Elysian Valley', 'Palms',
#        'Pico-Robertson', 'Sun Valley', 'Koreatown', 'San Pedro',
#        'Century City', 'Studio City', 'Beverly Crest', 'Westlake',
#        'Beverly Grove', 'Pasadena', 'Agua Dulce', 'Hermosa Beach',
#        'Baldwin Hills/Crenshaw', 'West Compton', 'Burbank',
#        'Arlington Heights', 'Leimert Park', 'Broadway-Manchester',
#        'Porter Ranch', 'Hancock Park', 'El Segundo', 'Inglewood',
#        'Covina', 'Rowland Heights', 'South Pasadena', 'Ladera Heights',
#        'Toluca Lake', 'La Canada Flintridge', 'Brentwood', 'Canoga Park',
#        'Lake Balboa', 'Rancho Park', 'Lincoln Heights', 'Alhambra',
#        'Baldwin Park', 'Montebello', 'Monrovia', 'Rolling Hills Estates',
#        'Winnetka', 'Whittier', 'Panorama City', 'Playa del Rey',
#        'Agoura Hills', 'Larchmont', 'San Gabriel', 'Playa Vista',
#        'Lomita', 'Eagle Rock', 'Windsor Square', 'Montecito Heights',
#        'West Adams', 'Reseda', 'Harbor City', 'West Hills', 'Palmdale',
#        'San Dimas', 'Sunland', 'Bel-Air', 'La Mirada',
#        'Rancho Palos Verdes', 'East Pasadena', 'Vermont Square',
#        'Hawthorne', 'Westwood', 'Northridge', 'Beverlywood',
#        'Signal Hill', 'Santa Clarita', 'San Fernando', 'University Park',
#        'West Covina', 'Marina del Rey', 'Arcadia', 'El Sereno', 'Sylmar',
#        'Hacienda Heights', 'Elysian Park', 'Granada Hills',
#        'Jefferson Park', 'East San Gabriel', 'West Carson', 'Gardena',
#        'Boyle Heights', 'Lancaster', 'North Whittier', 'Downey',
#        'Industry', 'Castaic Canyons', 'Adams-Normandie', 'Tarzana',
#        'East Los Angeles', 'Pico Rivera', 'Diamond Bar', 'Avalon',
#        'Monterey Park', 'Florence-Firestone', 'Exposition Park',
#        'Mayflower Village', 'El Monte', 'Veterans Administration',
#        'Athens', 'Claremont', 'Hyde Park', 'Sierra Madre', 'Bell',
#        'Val Verde', 'Chatsworth', 'Azusa', 'San Pasqual',
#        'Palos Verdes Estates', 'Sun Village', 'La Crescenta-Montrose',
#        'Compton', 'Cerritos', 'Willowbrook', 'Del Aire', 'Norwalk',
#        'Alondra Park', 'Stevenson Ranch', 'Pomona', 'Shadow Hills',
#        'Pico-Union', 'Chinatown', 'Temple City', 'Westmont',
#        'Unincorporated Santa Susana Mountains', 'Lawndale',
#        'Historic South-Central', 'Glendora', 'Duarte',
#        'South San Jose Hills', 'Vincent', 'Artesia', 'Sepulveda Basin',
#        'La Habra Heights', 'La Verne', 'Arleta', 'South Gate',
#        'Charter Oak', 'Angeles Crest', 'Northeast Antelope Valley',
#        'South San Gabriel', 'Vermont Vista', 'La Puente', 'Paramount',
#        'Cypress Park', 'Northwest Palmdale', 'Valinda', 'San Marino',
#        'Lake View Terrace', 'Green Meadows', 'Gramercy Park',
#        'Rancho Dominguez', 'Huntington Park', 'Lake Los Angeles',
#        'North El Monte', 'Rosemead', 'Bell Gardens', 'Castaic',
#        'Irwindale', 'Walnut', 'Santa Fe Springs',
#        'Southeast Antelope Valley', 'Desert View Highlands', 'Lennox',
#        'Rolling Hills', 'West Puente Valley', 'Watts', 'Quartz Hill',
#        'Maywood', 'Mission Hills', 'Vermont Knolls', 'South Whittier',
#        'Chesterfield Square', 'Universal City', 'Tujunga Canyons',
#        'Griffith Park', 'Westlake Village', 'Wilmington', 'Bradbury',
#        'West Whittier-Los Nietos', 'Green Valley', 'South Park',
#        'Avocado Heights', 'South El Monte', 'Lopez/Kagel Canyons',
#        'Hasley Canyon', 'Cudahy', 'Pacoima', 'Northwest Antelope Valley',
#        'Vermont-Slauson', 'Vernon', 'Manchester Square', 'Acton',
#        'Commerce', 'Citrus', 'East Compton', 'Harvard Park',
#        'Central-Alameda', 'South Diamond Bar', 'Florence', 'Ridge Route',
#        'Unincorporated Catalina Island', 'Hawaiian Gardens',
#        'East Whittier', 'Lake Hughes', 'Leona Valley', 'Elizabeth Lake',
#        'Mission Bay', 'Pacific Beach', 'Roseville', 'La Jolla',
#        'College Area', 'Midtown', 'Rancho Penasquitos', 'Del Mar Heights',
#        'Bay Park', 'West University Heights', 'Bird Land', 'Mira Mesa',
#        'Carmel Valley', 'Talmadge', 'Moreno Mission', 'Loma Portal',
#        'Torrey Pines', 'Linda Vista', 'Old Town', 'Darnall', 'Grant Hill',
#        'Scripps Ranch', 'Ocean Beach', 'Clairemont Mesa', 'Park West',
#        'Normal Heights', 'Midtown District', 'East Village', 'Core',
#        'Marina', 'Wooded Area', 'University City', 'Grantville',
#        'Cortez Hill', 'Serra Mesa', 'Balboa Park', 'Encanto',
#        'Gaslamp Quarter', 'Tijuana River Valley', 'Otay Ranch', 'Webster',
#        'North Clairemont', 'City Heights West', 'Sorrento Valley',
#        'Kensington', 'San Carlos', 'Sabre Springs', 'Columbia',
#        'Little Italy', 'Bay Ho', 'El Cerritos', 'Rancho Bernadino',
#        'Allied Gardens', 'Memorial', 'La Jolla Village', 'Kearny Mesa',
#        'Lake Murray', 'Palm City', 'Mission Valley', 'Northwest',
#        'Mountain View', 'Jomacha-Lomita', 'Rolando', 'Rancho Del Rey',
#        'Mount Hope', 'Rolling Hills Ranch', 'Paradise Hills',
#        'Tierrasanta', 'Lynwood Hills', 'Eastlake Vistas',
#        'Eastlake Woods', 'Southwest', 'Gateway',
#        'Amphitheater And Water Park', 'Oak Park', 'City Heights East',
#        'Del Cerro', 'Bay Terrace', 'Southcrest', 'Paseo Ranchoero',
#        'Yosemite Dr', 'Nestor', 'Sunbow', 'Estlake Greens',
#        'Carmel Mountain', 'Bario Logan', 'Terra Nova', 'North City',
#        'East Lake', 'San Ysidro', 'Sky Line', 'Bonita Long Canyon',
#        'Valencia Park', 'Lincoln Park', 'Chollas View', 'Emerald Hills',
#        'Alta Vista', 'Egger Highlands', 'Horton Plaza', 'Eastlake Trails',
#        'Western Addition', 'Bernal Heights', 'Haight Ashbury', 'Mission',
#        'Nob Hill', 'Downtown/Civic Center', 'Castro/Upper Market',
#        'Inner Sunset', 'Noe Valley', 'Twin Peaks', 'Potrero Hill',
#        'Outer Richmond', 'Glen Park', 'Ocean View', 'Pacific Heights',
#        'Financial District', 'South of Market', 'Russian Hill',
#        'Outer Sunset', 'Inner Richmond', 'Excelsior', 'Seacliff',
#        'West of Twin Peaks', 'Bayview', 'North Beach', 'Presidio',
#        'Presidio Heights', 'Diamond Heights', 'Parkside', 'Outer Mission',
#        'Lakeshore', 'Crocker Amazon', 'Golden Gate Park',
#        'Visitacion Valley', 'Menlo Park', 'Pacifica', 'East Palo Alto',
#        'Burlingame', 'Portola Valley', 'Atherton', 'Belmont', 'San Mateo',
#        'Half Moon Bay', 'Redwood City', 'Unincorporated Areas',
#        'Daly City', 'South San Francisco', 'Foster City', 'San Bruno',
#        'Hillsborough', 'Woodside', 'Millbrae', 'Colma', 'Brisbane',
#        'Santa Clara', 'Palo Alto', 'Cupertino', 'Sunnyvale', 'San Jose',
#        'Saratoga', 'Morgan Hill', 'Los Altos', 'Los Gatos',
#        'Los Altos Hills', 'Milpitas', 'Campbell', 'Gilroy',
#        'Monte Sereno', 'City of Santa Cruz', 'South Lawndale',
#        'West Town', 'Logan Square', 'Uptown', 'Near North Side',
#        'North Center', 'Lake View', 'Albany Park', 'Pullman',
#        'Near South Side', 'West Ridge', 'Near West Side', 'Edgewater',
#        'Bridgeport', 'Kenwood', 'Rogers Park', 'Lincoln Square',
#        'Grand Boulevard', 'Forest Glen', 'Loop', 'Lower West Side',
#        'Humboldt Park', 'East Garfield Park', 'North Lawndale',
#        'Irving Park', 'Oakland', 'Beverly', 'Chatham', 'Mckinley Park',
#        'Woodlawn', 'Avondale', 'Norwood Park', 'Portage Park',
#        'Washington Park', 'Morgan Park', 'Dunning', 'West Lawn',
#        'South Shore', 'Armour Square', 'South Deering',
#        'West Garfield Park', 'Hermosa', 'Douglas', 'Hegewisch',
#        'North Park', 'Greater Grand Crossing', 'West Elsdon',
#        'Belmont Cragin', 'Austin', 'Ashburn', 'Garfield Ridge',
#        'Brighton Park', 'Archer Heights', 'Ohare', 'Mount Greenwood',
#        'Edison Park', 'Englewood', 'Chicago Lawn', 'South Chicago',
#        'Gage Park', 'New City', 'Montclare', 'Clearing', 'Roseland',
#        'Calumet Heights', 'Fuller Park', 'Auburn Gresham',
#        'West Englewood', 'Avalon Park', 'Washington Heights', 'Burnside',
#        'Riverdale', 'East Side', 'West Pullman', 'Hallandale Beach',
#        'Dania Beach', 'Southwest Ranches', 'Deerfield Beach',
#        'Fort Lauderdale', 'Pompano Beach', 'Miramar', 'Coral Springs',
#        'Plantation', 'Cooper City', 'Sunrise', 'Lauderhill', 'Margate',
#        'Wilton Manors', 'Tamarac', 'Pembroke Pines', 'North Lauderdale',
#        'Lauderdale By The Sea', 'Oakland Park', 'Coconut Creek', 'Weston',
#        'Parkland', 'Hillsboro Beach', 'Davie', 'Lauderdale Lakes',
#        'Sea Ranch Lakes', 'Lighthouse Point', 'Unincorporated',
#        'Pembroke Park', 'West Park', 'Lazy Lake',
#        'County Regional Facility', 'Tribal Land', 'Hamakua',
#        'South Kohala', 'South Kona', 'North Kona', 'Koloa-Poipu',
#        'North Shore Kauai', 'Kihei-Makena', 'North Shore Oahu',
#        'Koolaupoko', 'Lahaina', 'Puna', 'Primary Urban Center',
#        'South Hilo', 'Paia-Haiku', 'Kapaa-Wailua', 'Waianae', 'Koolauloa',
#        'Ewa', 'North Kohala', 'Waimea-Kekaha', 'Molokai', 'East Honolulu',
#        'Wailuku-Kahului', 'Kau', 'Makawao-Pukalani-Kula', 'Lihue',
#        'North Hilo', 'Hana', 'Central Oahu', 'Lanai', 'Hanapepe-Eleele',
#        'Las Vegas', 'Clinton Hill', 'Bedford-Stuyvesant',
#        'Upper West Side', 'South Slope', 'Williamsburg', 'East Harlem',
#        'Fort Greene', "Hell's Kitchen", 'Harlem', 'Flatbush',
#        'Long Island City', 'Jamaica', 'Greenpoint', 'Kips Bay', 'Nolita',
#        'Chelsea', 'Upper East Side', 'Prospect Heights',
#        'Carroll Gardens', 'West Village', 'Park Slope', 'Gowanus',
#        'Flatlands', 'Flushing', 'Boerum Hill', 'Sunnyside',
#        'Lower East Side', 'Red Hook', 'St. George', 'Tribeca',
#        'Ridgewood', 'Port Morris', 'Morningside Heights',
#        'Middle Village', 'Ditmars Steinway', 'Cobble Hill',
#        'Flatiron District', 'Windsor Terrace', 'Roosevelt Island',
#        'Greenwich Village', 'Bushwick', 'Tompkinsville', 'Clason Point',
#        'Eastchester', 'Inwood', 'Crown Heights', 'Astoria', 'Kingsbridge',
#        'Brooklyn Heights', 'Sunset Park', 'Gramercy', 'Rockaway Beach',
#        'Forest Hills', 'Murray Hill', 'East Flatbush', 'SoHo',
#        'University Heights', 'Gravesend', 'Allerton', 'East New York',
#        'Theater District', 'Prospect-Lefferts Gardens', 'Stuyvesant Town',
#        'Emerson Hill', 'Fort Hamilton', 'Bensonhurst', 'Shore Acres',
#        'Elmhurst', 'Cypress Hills', 'Arrochar', 'Rego Park',
#        'Columbia St', 'Clifton', 'Bayside', 'Bay Ridge', 'Maspeth',
#        'Sheepshead Bay', 'Spuyten Duyvil', 'Stapleton', 'Briarwood',
#        'Morris Heights', 'Brighton Beach', 'Mott Haven',
#        'Jackson Heights', 'Battery Park City', 'Two Bridges',
#        'East Elmhurst', 'New Springville', 'Tottenville', 'NoHo',
#        'Concord', 'Borough Park', 'Downtown Brooklyn', 'Melrose',
#        'Kew Gardens', 'College Point', 'Civic Center', 'Navy Yard',
#        'DUMBO', 'Midwood', 'City Island', 'Concourse', 'Canarsie',
#        'Arverne', 'Richmond Hill', 'Queens Village', 'St. Albans',
#        'Brownsville', 'Williamsbridge', 'Soundview', 'Co-op City',
#        'Vinegar Hill', 'Parkchester', 'Bronxdale', 'Sea Gate',
#        'Ozone Park', 'Corona', 'Norwood', 'Claremont Village', 'Fordham',
#        'Woodhaven', 'Concourse Village', 'Fieldston', 'Eltingville',
#        'Wakefield', 'Lighthouse Hill', 'Unionport', 'Randall Manor',
#        'South Ozone Park', 'Kew Gardens Hills', 'Jamaica Estates',
#        'Dyker Heights', 'Mount Eden', 'Bellerose', 'Fresh Meadows',
#        'Morris Park', 'Far Rockaway', 'Mariners Harbor', 'Tremont',
#        'Springfield Gardens', 'Longwood', 'West Brighton', 'Marble Hill',
#        'Dongan Hills', 'Castleton Corners', 'Hunts Point', 'Neponsit',
#        'Great Kills', 'Pelham Bay', 'Morrisania', 'Grymes Hill',
#        'Laurelton', 'Holliswood', 'Edgemere', 'New Brighton',
#        'Pelham Gardens', 'Bath Beach', 'Baychester', 'Belle Harbor',
#        'Rosedale', 'Bergen Beach', 'Cambria Heights', 'Richmondtown',
#        'Howard Beach', 'Coney Island', 'Highbridge', 'Howland Hook',
#        "Prince's Bay", 'South Beach', 'Midland Beach', 'Oakwood',
#        'Hollis', 'Schuylerville', 'Huguenot', 'Edenwald',
#        'North Riverdale', 'Olinville', 'Port Richmond', 'Throgs Neck',
#        'Westerleigh', 'East Morrisania', 'Fort Wadsworth',
#        'Westchester Square', 'Douglaston', 'Bayswater', 'Van Nest',
#        'Arden Heights', "Bull's Head", 'Grant City', 'New Dorp',
#        'Castle Hill', 'New Dorp Beach', 'Todt Hill', 'Little Neck',
#        'Whitestone', 'Rosebank', 'Jamaica Hills', 'Rossville',
#        'Mill Basin', 'West Farms', 'Graniteville', 'Gerritsen Beach',
#        'Woodrow', 'Country Club', 'District 6', 'District 19',
#        'District 15', 'District 12', 'District 14', 'District 7',
#        'District 17', 'District 21', 'District 24', 'District 18',
#        'District 10', 'District 25', 'District 4', 'District 16',
#        'District 5', 'District 34', 'District 1', 'District 23',
#        'District 35', 'District 30', 'District 26', 'District 27',
#        'District 20', 'District 11', 'District 13', 'District 33',
#        'District 2', 'District 8', 'District 29', 'District 9',
#        'District 22', 'District 31', 'District 3', 'District 32',
#        'District 28', 'Takoma, Brightwood, Manor Park',
#        'Dupont Circle, Connecticut Avenue/K Street',
#        'Edgewood, Bloomingdale, Truxton Circle, Eckington',
#        'Historic Anacostia', 'Capitol Hill, Lincoln Park',
#        'Brightwood Park, Crestwood, Petworth',
#        'Colonial Village, Shepherd Park, North Portal Estates',
#        'Sheridan, Barry Farm, Buena Vista',
#        'Lamont Riggs, Queens Chapel, Fort Totten, Pleasant Hill',
#        'Union Station, Stanton Park, Kingman Park',
#        'Howard University, Le Droit Park, Cardozo/Shaw',
#        'Columbia Heights, Mt. Pleasant, Pleasant Plains, Park View',
#        'Shaw, Logan Circle',
#        'Spring Valley, Palisades, Wesley Heights, Foxhall Crescent, Foxhall Village, Georgetown Reservoir',
#        'Downtown, Chinatown, Penn Quarters, Mount Vernon Square, North Capitol Street',
#        'Georgetown, Burleith/Hillandale',
#        'Capitol View, Marshall Heights, Benning Heights',
#        'Cleveland Park, Woodley Park, Massachusetts Avenue Heights, Woodland-Normanstone Terrace',
#        'Kalorama Heights, Adams Morgan, Lanier Heights',
#        'Douglas, Shipley Terrace',
#        'Southwest Employment Area, Southwest/Waterfront, Fort McNair, Buzzard Point',
#        'River Terrace, Benning, Greenway, Dupont Park',
#        'Cathedral Heights, McLean Gardens, Glover Park',
#        'Friendship Heights, American University Park, Tenleytown',
#        'West End, Foggy Bottom, GWU', 'Brookland, Brentwood, Langdon',
#        'Ivy City, Arboretum, Trinidad, Carver Langston',
#        'Hawthorne, Barnaby Woods, Chevy Chase',
#        'Woodridge, Fort Lincoln, Gateway',
#        'Mayfair, Hillbrook, Mahaning Heights',
#        'Fairfax Village, Naylor Gardens, Hillcrest, Summit Park',
#        'Deanwood, Burrville, Grant Park, Lincoln Heights, Fairmont Heights',
#        'North Cleveland Park, Forest Hills, Van Ness',
#        'Congress Heights, Bellevue, Washington Highlands',
#        'North Michigan Park, Michigan Park, University Heights',
#        'Twining, Fairlawn, Randle Highlands, Penn Branch, Fort Davis Park, Fort Dupont',
#        'Near Southeast, Navy Yard', 'Eastland Gardens, Kenilworth',
#        'Woodland/Fort Stanton, Garfield Heights, Knox Hill', 'Madrona',
#        'Georgetown', 'Fairmount Park', 'Wallingford', 'High Point',
#        'Belltown', 'Whittier Heights', 'Loyal Heights', 'Mid-Beacon Hill',
#        'Windermere', 'Seward Park', 'Alki', 'North Admiral', 'Fremont',
#        'Green Lake', 'Harrison/Denny-Blaine', 'Portage Bay',
#        'Phinney Ridge', 'Crown Hill', 'Columbia City', 'Lawton Park',
#        'North Queen Anne', 'West Queen Anne', 'First Hill', 'Stevens',
#        'Eastlake', 'Broadway', 'Arbor Heights', 'Greenwood',
#        'North Beacon Hill', 'Wedgwood', 'Cedar Park', 'Pike-Market',
#        'Lower Queen Anne', 'Mount Baker', 'Mann', 'Genesee',
#        'Central Business District', 'Fauntleroy', 'Ravenna', 'Bryant',
#        'University District', 'South Delridge', 'Atlantic', 'Broadview',
#        'Adams', 'Maple Leaf', 'East Queen Anne', 'Pioneer Square',
#        'West Woodland', 'Montlake', 'Haller Lake', 'Madison Park',
#        'Leschi', 'Matthews Beach', 'Minor', 'Sunset Hill',
#        'North Beach/Blue Ridge', 'Briarcliff', 'Victory Heights',
#        'Brighton', 'Interbay', 'Bitter Lake', 'View Ridge',
#        'Southeast Magnolia', 'North Delridge', 'Seaview',
#        'Yesler Terrace', 'Holly Park', 'Dunlap', 'Rainier Beach',
#        'International District', 'Roosevelt', 'Pinehurst',
#        'Olympic Hills', 'North College Park', 'South Lake Union',
#        'Gatewood', 'Roxhill', 'Laurelhurst', 'Riverview', 'Meadowbrook',
#        'South Beacon Hill', 'Rainier View', 'Industrial District'],
#       dtype=object)

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Los Angeles', 'San Diego County', 'San Francisco', 'San Mateo',
#        'Saint Clara County', ' Santa Cruz', 'Chicago', 'Broward County',
#        'Hawaii', 'Kauai', 'Maui', 'Honolulu', 'Clark County', 'Manhattan',
#        'Brooklyn', 'Queens', 'Staten Island', 'Bronx', 'Nashville',
#        'Washington D.C', 'Seattle'], dtype=object)

# %%
df['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
df['accommodates'].unique()
# Out:
# array([ 6,  1,  2,  3,  4,  5,  8,  7, 10, 15, 12, 16,  9, 14, 11, 13,  0],
#       dtype=int64)

# %%
df['bedrooms'].unique()
# Out:
# array([ 2.,  1., nan,  3.,  4.,  6.,  5.,  7.,  9.,  8., 11., 12., 10.,
#        13., 50., 21., 14., 17., 16., 22., 15., 18., 37., 27.])

# %%
# initial and latest recorded year
min(pd.to_datetime(df['host_since'])),max(pd.to_datetime(df['host_since']))
# Out:
# (Timestamp('2008-02-12 00:00:00'), Timestamp('2020-12-11 00:00:00'))

# %% [markdown]
# **host_since:** we have data starting from 2008 to 2020

# %%
# Replacing blank with null and changing last_review & host_since columns to datetime format
df['last_review'] = pd.to_datetime(df['last_review'].replace(' ',np.nan))
df['host_since'] = pd.to_datetime(df['host_since'].replace(' ',np.nan))

# %%
# Spliting the Timestamp into year and month for host_since
df['host_since_yr']=pd.to_datetime(df['host_since']).dt.year
df['host_since_mnth']=pd.to_datetime(df['host_since']).dt.month
df.insert(loc=2, column='host_since_yr', value=df.pop('host_since_yr'))
df.insert(loc=3, column='host_since_mnth', value=df.pop('host_since_mnth'))

# %%
# Spliting the Timestamp into year and month for last_review
df['last_review_yr']=pd.to_datetime(df['last_review'],errors='coerce').dt.year
df['last_review_mnth']=pd.to_datetime(df['last_review'],errors='coerce').dt.month
df.insert(loc=26, column='last_review_yr', value=df.pop('last_review_yr'))
df.insert(loc=27, column='last_review_mnth', value=df.pop('last_review_mnth'))

# %%
# Dropping the redundant columns
df=df.drop(columns=['host_since','last_review'])

# %% [markdown]
# ### Numerical Columns - Analysis of distribution

# %%
iterator=1
plt.rcParams['figure.figsize']=[35,27]
for i in num_cols:
    
    plt.subplot(10,2,iterator)
    #plt.title(i)
    sns.kdeplot(df[i])
    iterator+=1
plt.tight_layout()
plt.show()

# %%
skew=df.loc[:,list(num_cols)].skew()
d=pd.DataFrame()
d['skewness']=skew
def skew1(i):
    #print(i)
    if float(i) > 0.5:
        return 'Positive'
    elif i <  -0.5:
        return 'Negative'
    else:
        return 'Normal'

d['skewness_type']=d['skewness'].apply(skew1)
        
# skewness of numerical columns in the dataset
d
# Out:
#                                   skewness skewness_type
# id                               -0.278879        Normal
# host_id                           1.073491      Positive
# accommodates                      1.739753      Positive
# latitude                         -0.816761      Negative
# longitude                        -0.327570        Normal
# bathrooms                         5.498819      Positive
# bedrooms                          3.568073      Positive
# beds                              4.687372      Positive
# price                            22.880892      Positive
# minimum_nights                  397.805222      Positive
# maximum_nights                  395.209453      Positive
# number_of_reviews                 3.152925      Positive
# reviews_per_month                 2.575245      Positive
# calculated_host_listings_count    4.133847      Positive
# availability_365                  0.041817        Normal

# %% [markdown]
# **The skewness of the numerical columns are explained by the above dataframe.**

# %%
# Standard deviation over each numerical columns
df.loc[:,list(num_cols)].std()
# Out:
# id                                1.391386e+07
# host_id                           1.045460e+08
# accommodates                      2.644270e+00
# latitude                          6.938362e+00
# longitude                         2.796584e+01
# bathrooms                         8.781675e-01
# bedrooms                          1.061445e+00
# beds                              1.790110e+00
# price                             5.002285e+02
# minimum_nights                    2.513793e+05
# maximum_nights                    5.410484e+06
# number_of_reviews                 2.780842e+02
# reviews_per_month                 1.638515e+00
# calculated_host_listings_count    4.888697e+01
# availability_365                  1.391774e+02
# dtype: float64

# %% [markdown]
# #### All columns are having certain standard deviation, thus each columns are significant and adds value to the model.

# %%
cat_cols1=['host_name', 'host_is_superhost', 'host_identity_verified',
       'instant_bookable', 'State', 'neighbourhood_group',
       'neighbourhood', 'property_type', 'room_type']
# Categorical columns
iterator=1
plt.rcParams['figure.figsize']=[15,20]
for i in cat_cols1:
    plt.subplot(5,2,iterator)
    plt.title(i)
    df[i].value_counts()[:20].plot(kind='bar')
    iterator+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# * **Host_name:** Kia has the highest number of listings in Seattle, followed by Micheal and David.
# * **Host_is_superhost:** Majority of the hosts are not super hosts.
# * **Host_is_verified:** Majority of the hosts are verified.
# * **Instant_bookable:** Instant bookable option is not available in most of the listings.
# * **State:** California has the highest number of listings followed by Newyork.
# * **Neighbourhood_group:** Los Angeles has the highest number of listing in the neighbourhood group.
# * **Neighbourhood:** Los Vegas has the highest number of listing in the neighbourhood.
# * **Property_Type:** Entire Appartment has the highest count in the property listings based on property type.
# * **Room_type:** Entire home/Apt has the highest count in the property listings based on room type.

# %% [markdown]
# #### target variable analysis

# %%
plt.rcParams['figure.figsize']=[15,5]
sns.distplot(df['price'])
plt.show()
print('Skewness of price variable: ',df['price'].skew())
# Out:
# Skewness of price variable:  22.880891758896077

# %%
plt.rcParams['figure.figsize']=[25,5]
sns.boxplot(df['price'])
plt.show()

# %% [markdown]
# * **Target Variable(Price):** we can see that there are more number of outliers present in the target data.

# %% [markdown]
# ### Bivariate Analysis

# %%
num_cols = ['id', 'host_id', 'accommodates', 'latitude', 'longitude', 'bathrooms',
            'bedrooms', 'beds',  'minimum_nights', 'maximum_nights',
            'number_of_reviews', 'reviews_per_month',
            'calculated_host_listings_count', 'availability_365']
# Numerical columns
iterator=1
plt.rcParams['figure.figsize']=[30,20]
for i in num_cols:
    plt.subplot(7,2,iterator)
    sns.scatterplot(df[i],df['price'])
    iterator+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# **From the above graphs we can see that there isn't much relationship between the target variable and the numerical variable**

# %%
ccols1=['host_is_superhost',
     'host_identity_verified',
     'instant_bookable',
     'State',
     'neighbourhood_group',
     'room_type']
#Cat vs Num
r=3
c=2
itr=1
plt.rcParams['figure.figsize']=[15,10]
for i in ccols1:
    plt.subplot(r,c,itr)
    plt.xticks(rotation=90)
    sns.barplot(data=df,x=i,y='price')
    #df.groupby(i)['price'].mean().plot(kind='bar')
    itr+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# * **Host_is_superhost:** Average prices are almost equal for both superhosts and non-superhosts.
# * **Host_is_verified:** Average prices are almost equal for the listings which are verified and unverified.
# * **Instant_bookable:** Average prices are almost equal whether there is a availability of instant booking or not.
# * **State:** Average price in Hawaii is greater than compared to other states.
# * **Neighbourhood_group:** Average price in Maui neighbour hood group is greater than compared to others.
# * **Room_type:** Average prices in hotel rooms and Entire home/apt are almost equal and higher than the other room types.

# %%
fig,axes=plt.subplots(3,2)
pd.crosstab(df['host_identity_verified'], df['host_is_superhost']).plot(kind='bar',ax=axes[0,0])
pd.crosstab(df['instant_bookable'], df['host_is_superhost']).plot(kind='bar',ax=axes[1,0])
pd.crosstab(df['State'], df['host_is_superhost']).plot(kind='bar',ax=axes[1,1])
pd.crosstab(df['neighbourhood_group'], df['host_is_superhost']).plot(kind='bar',ax=axes[2,0])
pd.crosstab(df['room_type'], df['host_is_superhost']).plot(kind='bar',ax=axes[2,1])
plt.delaxes(axes[0,1])
plt.tight_layout()
plt.show()

# %% [markdown]
# * Identify verified for superhosts is higher than non verified.
# * Instant bookability provided by superhosts are higher than non general hosts
# * The highest number of superhosts are recorded in California and succeedingly Hawaii
# * The number of superhosts are recorded highly in Los Angeles
# * High number of superhosts offer Entire home/Apartment type of room

# %% [markdown]
# ### Multivariate Analysis

# %%
plt.rcParams['figure.figsize']=[20,15]
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# * On comparing with the target variable there isnt much correlation between the variables.
# * But there is multi collinearity is present between the columns **accomodates, beds, bathroom and bedrooms**
# * Also multicollinearity between **host id** and **Host since year**
# * **Latitude** and **Longitude** has moderately strong multi collinearaity between them .

# %% [markdown]
# ## Unique Identifier

# %%
df.loc[(df['id'].duplicated()),'id'].unique()
# Out:
# array([14906035, 45805136, 20995666, 44615487, 45546430, 45546628,
#        45546789, 45546863, 45546968, 46006058, 46006560, 46006648,
#        46006814, 46006931, 45623908], dtype=int64)

# %%
# Dropping the duplicated indentity
df['id'].drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (158249, 30)

# %% [markdown]
# ### Missing Values

# %%
# row wise missing values
df.isnull().sum(axis=1)[df.isnull().sum(axis=1) == len(list(df.columns))]


# all rows are having atleast one column filled with data
# Out:
# Series([], dtype: int64)

# %%
# Column wise Null values
percentage_result = df.isnull().sum()/df.shape[0] * 100
count=df.isnull().sum()
percentage_result = pd.DataFrame({"columns": percentage_result.keys(),'count of missing':count, "% missing": percentage_result})
percentage_result.reset_index(drop=True, inplace=True)
percentage_result[percentage_result['count of missing']>0]
# Out:
#                    columns  count of missing  % missing
# 1                     name                18   0.011374
# 2            host_since_yr                29   0.018326
# 3          host_since_mnth                29   0.018326
# 5                host_name                29   0.018326
# 6        host_is_superhost                29   0.018326
# 7   host_identity_verified                29   0.018326
# 18               bathrooms               184   0.116272
# 19                bedrooms             16635  10.511915
# 20                    beds              1284   0.811380
# 25          last_review_yr             36556  23.100304
# 26        last_review_mnth             36556  23.100304
# 27       reviews_per_month             36555  23.099672

# %%
# Visualisation of null values in the data set
sns.heatmap(df.isnull())
plt.show()

# %%
# Checking for duplicated rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, host_since_yr, host_since_mnth, host_id, host_name, host_is_superhost, host_identity_verified, instant_bookable, accommodates, amenities, State, neighbourhood_group, neighbourhood, latitude, longitude, property_type, room_type, bathrooms, bedrooms, beds, price, minimum_nights, maximum_nights, number_of_reviews, last_review_yr, last_review_mnth, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# * **No duplicate rows identified**

# %% [markdown]
# ### Treating Null Values

# %%
# Identifying the null values in host_name and other attributes
df[df.host_name.isnull()]
# Out:
#               id                                                name  \
# 3530     6900415                           Quiet, Cozy West LA House
# 4937    10034835                      Large private bedroom in Palms
# 13327   24304179   Hillside Bungalow + Patio & Parking hills of UCLA
# 21944   38358017   Modern Beachfront Guest Suite Hidden Ocean Escape
# 33318   14116320                              Modern La Jolla Escape
# 33319   14116330                                     Villa Portofino
# 33320   14116332                                       Forever Views
# 63414    8918724                        Downtown Hollywood Apartment
# 63807   12536002                  Cozy apartment Downtown Hollywood.
# 64394   16879934  HUGE LAKE VIEW MASTER BDRM  (sleeps 2) near weston
# 65659   23821844                                 Hollywood Apartment
# 106454   2835711    Sunny West Village Apartment on MacDougal Street
# 107621   4446862                  Charming Room in Prospect Heights!
# 107960   4763327                 Luxurious, best location, spa inc'l
# 109079   6360224                     Sunny, Private room in Bushwick
# 109666   6992973                     1 Bedroom in Prime Williamsburg
# 110099   7556587                                Sunny Room in Harlem
# 110508   8007908           Rare Find: Stylish West Village Townhouse
# 116016  15494796  Private Guest Room in Charming West Village Duplex
# 121925  23715974        Spacious & Sunny Central Park West Apartment
# 141592  15820455                  1 BR Condo Downtown/Nissan Stadium
# 154104   1614502     Beautiful Private Room & Bath, central location
# 154132   1956274                     Sweet Ballard Apartment for Two
# 155162  16338772           Spacious 1-BDRM Apartment in West Seattle
# 155304  18182005                            Madison Park Family Home
# 155723  22292161                                       Garden studio
# 156707  35162444     Cute shared house w/2Bed rooms  near light rail
# 157126  39780119               Beacon Hill Renovated Mid/Century Gem
# 158206  45915379                     Cozy Sanctuary of Color and Art
#
#         host_since_yr  host_since_mnth    host_id host_name host_is_superhost  \
# 3530              NaN              NaN   36159573       NaN               NaN
# 4937              NaN              NaN   23571738       NaN               NaN
# 13327             NaN              NaN    5112516       NaN               NaN
# 21944             NaN              NaN  291648183       NaN               NaN
# 33318             NaN              NaN   66115585       NaN               NaN
# 33319             NaN              NaN   66115585       NaN               NaN
# 33320             NaN              NaN   66115585       NaN               NaN
# 63414             NaN              NaN   14684610       NaN               NaN
# 63807             NaN              NaN   14684610       NaN               NaN
# 64394             NaN              NaN  104917254       NaN               NaN
# 65659             NaN              NaN   14684610       NaN               NaN
# 106454            NaN              NaN    3237504       NaN               NaN
# 107621            NaN              NaN   23077718       NaN               NaN
# 107960            NaN              NaN   24576978       NaN               NaN
# 109079            NaN              NaN   33134899       NaN               NaN
# 109666            NaN              NaN    5162530       NaN               NaN
# 110099            NaN              NaN   39608626       NaN               NaN
# 110508            NaN              NaN     390117       NaN               NaN
# 116016            NaN              NaN     390117       NaN               NaN
# 121925            NaN              NaN    3635762       NaN               NaN
# 141592            NaN              NaN  103457933       NaN               NaN
# 154104            NaN              NaN    8594245       NaN               NaN
# 154132            NaN              NaN    7466082       NaN               NaN
# 155162            NaN              NaN   43428773       NaN               NaN
# 155304            NaN              NaN   16151000       NaN               NaN
# 155723            NaN              NaN     672972       NaN               NaN
# 156707            NaN              NaN     862329       NaN               NaN
# 157126            NaN              NaN    1472487       NaN               NaN
# 158206            NaN              NaN   48973090       NaN               NaN
#
#        host_identity_verified instant_bookable  accommodates  \
# 3530                      NaN                f             3
# 4937                      NaN                f             3
# 13327                     NaN                t             2
# 21944                     NaN                t             2
# 33318                     NaN                t            12
# 33319                     NaN                t            10
# 33320                     NaN                t            11
# 63414                     NaN                f             4
# 63807                     NaN                f             4
# 64394                     NaN                f             2
# 65659                     NaN                f             4
# 106454                    NaN                f             3
# 107621                    NaN                f             2
# 107960                    NaN                f             4
# 109079                    NaN                f             1
# 109666                    NaN                f             4
# 110099                    NaN                f             2
# 110508                    NaN                f             5
# 116016                    NaN                f             2
# 121925                    NaN                f             4
# 141592                    NaN                f             2
# 154104                    NaN                f             3
# 154132                    NaN                f             2
# 155162                    NaN                t             4
# 155304                    NaN                f            10
# 155723                    NaN                f             2
# 156707                    NaN                f             4
# 157126                    NaN                t             4
# 158206                    NaN                f             2
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   amenities  \
# 3530                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ["Fire extinguisher", "Wifi", "Kitchen", "Washer", "Essentials", "Free parking on premises", "First aid kit"]
# 4937                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ["Smoke alarm", "Pool", "Iron", "Carbon monoxide alarm", "Wifi", "Dryer", "Laptop-friendly workspace", "TV", "Washer", "Kitchen", "Hangers", "Heating", "Free parking on premises"]
# 13327                                           ["Cable TV", "Beach essentials", "Air conditioning", "Carbon monoxide alarm", "Hangers", "Fire extinguisher", "Kitchen", "Hair dryer", "Garden or backyard", "Heating", "Free parking on premises", "Keypad", "Private entrance", "Luggage dropoff allowed", "Single level home", "Laptop-friendly workspace", "Bathtub", "Washer", "Dishes and silverware", "Refrigerator", "BBQ grill", "First aid kit", "Smoke alarm", "Patio or balcony", "Free street parking", "Ethernet connection", "EV charger", "Iron", "Coffee maker", "Wifi", "TV", "Hot water", "Essentials", "Shampoo", "Bed linens", "Microwave", "Pocket wifi", "Oven", "Extra pillows and blankets", "Stove", "Dryer", "Dishwasher", "Room-darkening shades", "Cooking basics", "Long term stays allowed"]
# 21944                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ["Smoke alarm", "Private entrance", "Free street parking", "Microwave", "Iron", "Coffee maker", "Hot water", "Air conditioning", "Carbon monoxide alarm", "Wifi", "Laptop-friendly workspace", "TV", "Hangers", "Hair dryer", "Essentials", "Keypad", "First aid kit", "Shampoo"]
# 33318                                                                                                                                                                                                                                                                                                                                                                 ["Pool", "Garden or backyard", "Indoor fireplace", "TV", "Essentials", "Patio or balcony", "Microwave", "Air conditioning", "Free parking on premises", "Cable TV", "Fire extinguisher", "Washer", "Wifi", "Dryer", "Oven", "Gym", "Kitchen", "Hair dryer", "Hot tub", "Refrigerator", "Coffee maker", "Heating", "Bed linens", "Hangers", "BBQ grill", "Iron", "Smoke alarm", "Dishwasher", "Free street parking", "Dishes and silverware", "Stove"]
# 33319                                                                                                                                                                                                                                                                                                                                                                                       ["Pool", "Indoor fireplace", "TV", "Essentials", "Patio or balcony", "Microwave", "Air conditioning", "Free parking on premises", "Cable TV", "Fire extinguisher", "Washer", "Wifi", "Dryer", "Oven", "Gym", "Kitchen", "Hair dryer", "Hot tub", "Refrigerator", "Coffee maker", "Heating", "Bed linens", "Hangers", "BBQ grill", "Iron", "Smoke alarm", "Dishwasher", "Free street parking", "Dishes and silverware", "Stove"]
# 33320                                                                                                                                                                                                                                                                                                                                                                                                                     ["Pool", "Indoor fireplace", "TV", "Essentials", "Patio or balcony", "Microwave", "Air conditioning", "Free parking on premises", "Cable TV", "Fire extinguisher", "Wifi", "Dryer", "Oven", "Kitchen", "Hair dryer", "Hot tub", "Coffee maker", "Refrigerator", "Heating", "Bed linens", "Hangers", "BBQ grill", "Iron", "Smoke alarm", "Dishwasher", "Washer", "Dishes and silverware", "Stove"]
# 63414                                                                                                                                                                                                                                                                                                                                                                                                                                        ["Refrigerator", "Building staff", "Pool", "Hair dryer", "Heating", "Cooking basics", "Dishes and silverware", "Smoke alarm", "Paid parking on premises", "Dishwasher", "Wifi", "Fire extinguisher", "Cable TV", "Shampoo", "Gym", "Kitchen", "Microwave", "Air conditioning", "Elevator", "TV", "Essentials", "Carbon monoxide alarm", "Waterfront", "Coffee maker", "Stove"]
# 63807                                                                                                                                                                                              ["Refrigerator", "Laptop-friendly workspace", "Hair dryer", "Heating", "Dishes and silverware", "Beach essentials", "Smoke alarm", "Private entrance", "Bed linens", "Outlet covers", "Wifi", "Hangers", "Fire extinguisher", "Shampoo", "Extra pillows and blankets", "Breakfast", "Kitchen", "Single level home", "Lockbox", "Microwave", "Air conditioning", "Pack \u2019n Play/travel crib", "First aid kit", "Hot water", "Iron", "TV", "Essentials", "Carbon monoxide alarm", "Patio or balcony", "Coffee maker", "Free parking on premises", "Children\u2019s books and toys", "Garden or backyard", "BBQ grill"]
# 64394                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ["Pool", "Air conditioning", "Smoke alarm", "Heating", "Washer", "Fire extinguisher", "Hot tub", "Free parking on premises", "Gym", "Kitchen", "TV", "Dryer"]
# 65659                                                                                                                                                                                                                                                                             ["Refrigerator", "Laptop-friendly workspace", "Hair dryer", "Cooking basics", "Dishes and silverware", "Oven", "Smoke alarm", "Room-darkening shades", "Bed linens", "Wifi", "Hangers", "Fire extinguisher", "Shampoo", "Extra pillows and blankets", "Kitchen", "Single level home", "Dryer", "Lockbox", "Microwave", "Air conditioning", "First aid kit", "Washer", "Hot water", "Iron", "TV", "Essentials", "Carbon monoxide alarm", "Coffee maker", "Free street parking", "Free parking on premises", "Garden or backyard", "Stove"]
# 106454                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ["Wifi", "Dishes and silverware", "Heating", "Hot water", "Cooking basics", "Oven", "Essentials", "Microwave", "Refrigerator", "Shampoo", "Air conditioning", "Dedicated workspace", "Host greets you", "Stove", "Hangers", "Long term stays allowed", "Kitchen", "Hair dryer", "Smoke alarm"]
# 107621                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ["Wifi", "Heating", "Essentials", "Air conditioning", "Kitchen", "TV", "Carbon monoxide alarm", "Smoke alarm"]
# 107960                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ["Wifi", "Heating", "Gym", "Essentials", "Cable TV", "Dryer", "Air conditioning", "Elevator", "Pool", "Hot tub", "Washer", "Kitchen", "TV", "Smoke alarm"]
# 109079                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ["Wifi", "First aid kit", "Heating", "Essentials", "Air conditioning", "Kitchen", "Carbon monoxide alarm", "Smoke alarm"]
# 109666                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ["Shampoo", "Fire extinguisher", "Essentials", "Air conditioning", "Kitchen", "Carbon monoxide alarm", "Smoke alarm"]
# 110099                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ["Wifi", "Heating", "Elevator", "Kitchen", "Smoke alarm"]
# 110508                                                                                                                                                                                                                                                                                                                                                                                                           ["Hot water", "Shampoo", "Oven", "Patio or balcony", "Hot tub", "Iron", "Washer", "TV", "Wifi", "Refrigerator", "Dryer", "Dedicated workspace", "Air conditioning", "Dishwasher", "Smoke alarm", "Dishes and silverware", "Heating", "Essentials", "Garden or backyard", "Smart lock", "Hair dryer", "Coffee maker", "Cooking basics", "Cable TV", "Stove", "Hangers", "Kitchen", "Carbon monoxide alarm"]
# 116016                                                                                                                                                                                                                                                                                                                                      ["Hot water", "Shampoo", "Oven", "Patio or balcony", "Iron", "Washer", "Long term stays allowed", "TV", "Wifi", "Refrigerator", "Dryer", "Dedicated workspace", "Air conditioning", "Dishwasher", "Lockbox", "Breakfast", "Smoke alarm", "Dishes and silverware", "Heating", "Fire extinguisher", "Essentials", "Paid parking off premises", "Hair dryer", "Coffee maker", "Cooking basics", "Luggage dropoff allowed", "Stove", "Hangers", "Kitchen", "Carbon monoxide alarm"]
# 121925                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ["Wifi", "Heating", "Hot water", "Shampoo", "Essentials", "Dryer", "Free street parking", "Dedicated workspace", "Air conditioning", "Elevator", "Hair dryer", "Hangers", "Private entrance", "Washer", "Kitchen", "TV", "Carbon monoxide alarm", "Smoke alarm"]
# 141592                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ["TV", "Elevator", "Free parking on premises", "Air conditioning", "Smoke alarm", "Washer", "Kitchen", "Wifi", "Shampoo", "Laptop-friendly workspace", "Iron", "Cable TV", "Essentials", "First aid kit", "Hair dryer", "Heating", "Fire extinguisher", "Hangers", "Dryer"]
# 154104                                                                                                                                                                                                                                       ["Iron", "TV", "Hangers", "Lock on bedroom door", "Hair dryer", "Carbon monoxide alarm", "Luggage dropoff allowed", "Microwave", "Dishwasher", "Wifi", "Smoke alarm", "Extra pillows and blankets", "Refrigerator", "Kitchen", "Dishes and silverware", "Stove", "Coffee maker", "Free street parking", "Cooking basics", "Keypad", "Shampoo", "Laptop-friendly workspace", "Bed linens", "Paid parking on premises", "Oven", "First aid kit", "Hot water", "Fire extinguisher", "Garden or backyard", "Long term stays allowed", "Patio or balcony", "Heating", "Essentials"]
# 154132                                                                                                                                                              ["Conditioner", "Iron", "TV", "Hangers", "Cable TV", "Private entrance", "Hair dryer", "Carbon monoxide alarm", "Luggage dropoff allowed", "Microwave", "Dishwasher", "Wifi", "Smoke alarm", "Extra pillows and blankets", "Refrigerator", "Kitchen", "Washer", "Dishes and silverware", "Single level home", "Stove", "Coffee maker", "Free street parking", "Cooking basics", "Keypad", "Shampoo", "Laptop-friendly workspace", "Bed linens", "Free parking on premises", "Portable fans", "Oven", "First aid kit", "Hot water", "Fire extinguisher", "Garden or backyard", "Dryer", "Long term stays allowed", "Body soap", "Heating", "Essentials"]
# 155162                                                                                                                                                                                                                                                                                                                                                                      ["Children\u2019s books and toys", "TV", "Hangers", "Cable TV", "Hair dryer", "Carbon monoxide alarm", "Wifi", "Smoke alarm", "Extra pillows and blankets", "Kitchen", "Dishes and silverware", "Coffee maker", "Free street parking", "Keypad", "Shampoo", "Laptop-friendly workspace", "Free parking on premises", "First aid kit", "Fire extinguisher", "Long term stays allowed", "Heating", "Pack \u2019n Play/travel crib", "Essentials"]
# 155304  ["Outlet covers", "Children\u2019s books and toys", "Bathtub", "Iron", "TV", "Hangers", "Cable TV", "Private entrance", "Hair dryer", "Carbon monoxide alarm", "Air conditioning", "Luggage dropoff allowed", "Microwave", "Dishwasher", "Wifi", "Children\u2019s dinnerware", "Extra pillows and blankets", "Smoke alarm", "Refrigerator", "Kitchen", "Indoor fireplace", "Washer", "Pocket wifi", "Dishes and silverware", "Stove", "Coffee maker", "Free street parking", "Cooking basics", "Keypad", "Shampoo", "BBQ grill", "Laptop-friendly workspace", "Bed linens", "Oven", "First aid kit", "Hot water", "Fire extinguisher", "Garden or backyard", "Dryer", "High chair", "Long term stays allowed", "Patio or balcony", "Heating", "Crib", "Pack \u2019n Play/travel crib", "Essentials", "Lake access"]
# 155723                                                                                                                                                                                                                                                                                                         ["Iron", "Hangers", "Private entrance", "Hair dryer", "Carbon monoxide alarm", "Microwave", "Wifi", "Smoke alarm", "Extra pillows and blankets", "Refrigerator", "Kitchen", "Washer", "Dishes and silverware", "Single level home", "Stove", "Coffee maker", "Free street parking", "Cooking basics", "Keypad", "Shampoo", "Laptop-friendly workspace", "Bed linens", "Oven", "First aid kit", "Hot water", "Fire extinguisher", "Garden or backyard", "Dryer", "Patio or balcony", "Heating", "Essentials"]
# 156707                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ["Hot water", "Wifi", "Shampoo", "Smoke alarm", "Fire extinguisher", "Dryer", "Laptop-friendly workspace", "Iron", "Kitchen", "Hangers", "Heating", "Washer", "Essentials", "Hair dryer", "Lock on bedroom door", "Carbon monoxide alarm", "First aid kit"]
# 157126                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ["Free street parking", "Cooking basics", "Wifi", "Fire extinguisher", "Smoke alarm", "Dryer", "Laptop-friendly workspace", "Iron", "TV", "Kitchen", "Hangers", "Heating", "Private entrance", "Washer", "Essentials", "Hair dryer", "Dishes and silverware", "Carbon monoxide alarm", "Elevator", "Air conditioning"]
# 158206                                                                                                                                                                                                                                                                                                                                  ["Iron", "Hangers", "Private entrance", "Hair dryer", "Carbon monoxide alarm", "Luggage dropoff allowed", "Microwave", "Wifi", "Smoke alarm", "Extra pillows and blankets", "Refrigerator", "Washer", "Dishes and silverware", "Coffee maker", "Free street parking", "Keypad", "Shampoo", "Laptop-friendly workspace", "Bed linens", "Free parking on premises", "First aid kit", "Hot water", "Fire extinguisher", "Gym", "Garden or backyard", "Dryer", "Heating", "Essentials"]
#
#              State neighbourhood_group        neighbourhood  latitude  \
# 3530    California         Los Angeles            Mar Vista  34.00105
# 4937    California         Los Angeles                Palms  34.03038
# 13327   California         Los Angeles        Beverly Crest  34.10544
# 21944   California         Los Angeles    Pacific Palisades  34.04212
# 33318   California    San Diego County             La Jolla  32.83401
# 33319   California    San Diego County             La Jolla  32.84583
# 33320   California    San Diego County             La Jolla  32.82395
# 63414      Florida      Broward County            Hollywood  26.01596
# 63807      Florida      Broward County            Hollywood  26.01596
# 64394      Florida      Broward County              Miramar  25.99092
# 65659      Florida      Broward County            Hollywood  26.01678
# 106454   New York            Manhattan    Greenwich Village  40.73083
# 107621   New York             Brooklyn        Crown Heights  40.67512
# 107960   New York             Brooklyn           Greenpoint  40.72035
# 109079   New York             Brooklyn             Bushwick  40.70146
# 109666   New York             Brooklyn         Williamsburg  40.71838
# 110099   New York            Manhattan               Harlem  40.82929
# 110508   New York            Manhattan         West Village  40.73221
# 116016   New York            Manhattan         West Village  40.73313
# 121925   New York            Manhattan  Morningside Heights  40.80307
# 141592   Tennessee           Nashville           District 5  36.17410
# 154104  Washington             Seattle                Minor  47.61025
# 154132  Washington             Seattle                Adams  47.66869
# 155162  Washington             Seattle             Gatewood  47.54302
# 155304  Washington             Seattle         Madison Park  47.64124
# 155723  Washington             Seattle               Leschi  47.59339
# 156707  Washington             Seattle      Mid-Beacon Hill  47.54435
# 157126  Washington             Seattle         Madison Park  47.63944
# 158206  Washington             Seattle         Rainier View  47.50597
#
#         longitude                property_type        room_type  bathrooms  \
# 3530   -118.43665                 Entire house  Entire home/apt        1.0
# 4937   -118.41465    Private room in apartment     Private room        1.0
# 13327  -118.44618              Entire bungalow  Entire home/apt        1.0
# 21944  -118.56424  Private room in guest suite     Private room        1.0
# 33318  -117.25341                 Entire house  Entire home/apt        4.5
# 33319  -117.26151                 Entire house  Entire home/apt        4.5
# 33320  -117.24517                 Entire house  Entire home/apt        4.5
# 63414   -80.14198             Entire apartment  Entire home/apt        1.0
# 63807   -80.14198             Entire apartment  Entire home/apt        1.0
# 64394   -80.39513        Private room in house     Private room        1.0
# 65659   -80.14256             Entire apartment  Entire home/apt        1.0
# 106454  -74.00060             Entire apartment  Entire home/apt        1.0
# 107621  -73.96146    Private room in apartment     Private room        1.0
# 107960  -73.95355             Entire apartment  Entire home/apt        1.0
# 109079  -73.92792    Private room in apartment     Private room        0.0
# 109666  -73.95630             Entire apartment  Entire home/apt        2.0
# 110099  -73.94182    Private room in apartment     Private room        1.0
# 110508  -74.00928             Entire townhouse  Entire home/apt        2.0
# 116016  -74.00888    Private room in apartment     Private room        2.0
# 121925  -73.95869             Entire apartment  Entire home/apt        1.0
# 141592  -86.76502  Private room in condominium     Private room        1.0
# 154104 -122.30505        Private room in house     Private room        1.0
# 154132 -122.39609           Entire guest suite  Entire home/apt        1.5
# 155162 -122.38457             Entire apartment  Entire home/apt        1.0
# 155304 -122.28100                 Entire house  Entire home/apt        2.5
# 155723 -122.29370                 Entire house  Entire home/apt        1.0
# 156707 -122.28478        Private room in house     Private room        1.0
# 157126 -122.27780           Entire condominium  Entire home/apt        2.0
# 158206 -122.26452           Entire guest suite  Entire home/apt        1.0
#
#         bedrooms  beds  price  minimum_nights  maximum_nights  \
# 3530         1.0   2.0     99              30            1125
# 4937         1.0   1.0     41              30            1125
# 13327        1.0   1.0    145              30            1125
# 21944        NaN   1.0    206               1            1125
# 33318        4.0   5.0   1830               1            1125
# 33319        4.0   4.0   3049               1            1125
# 33320        5.0   5.0   1708               1            1125
# 63414        1.0   3.0     94               3              90
# 63807        1.0   3.0     89               3              90
# 64394        1.0   1.0     99              30             180
# 65659        1.0   2.0     89               3              90
# 106454       1.0   2.0     64              30             200
# 107621       1.0   1.0     50              30            1125
# 107960       1.0   2.0    195              30            1125
# 109079       1.0   1.0     37              30            1125
# 109666       2.0   1.0    145              30            1125
# 110099       1.0   1.0     28              30            1125
# 110508       3.0   3.0    375              30              60
# 116016       1.0   1.0    100               1            1125
# 121925       1.0   1.0    100              30            1125
# 141592       1.0   1.0    110             180            1125
# 154104       1.0   1.0     78               2              45
# 154132       1.0   1.0    125               3            1125
# 155162       1.0   2.0     93               2              30
# 155304       4.0   5.0    369               1             300
# 155723       1.0   1.0     57               2            1125
# 156707       2.0   2.0     89              30              90
# 157126       2.0   2.0    175               3              33
# 158206       1.0   1.0     31               1               7
#
#         number_of_reviews  last_review_yr  last_review_mnth  \
# 3530                    0             NaN               NaN
# 4937                    2          2015.0              12.0
# 13327                  50          2019.0              10.0
# 21944                  30          2020.0              10.0
# 33318                   0             NaN               NaN
# 33319                   0             NaN               NaN
# 33320                   0             NaN               NaN
# 63414                 114          2020.0              11.0
# 63807                 108          2020.0               3.0
# 64394                   0             NaN               NaN
# 65659                  38          2020.0               3.0
# 106454                 45          2020.0              11.0
# 107621                  0             NaN               NaN
# 107960                  1          2015.0              10.0
# 109079                  1          2015.0               1.0
# 109666                  0             NaN               NaN
# 110099                  1          2015.0               1.0
# 110508                 23          2020.0               5.0
# 116016                  8          2019.0               4.0
# 121925                  0             NaN               NaN
# 141592                  4          2017.0               2.0
# 154104                178          2020.0               3.0
# 154132                182          2020.0              11.0
# 155162                 76          2020.0              10.0
# 155304                 71          2020.0              12.0
# 155723                 63          2020.0              10.0
# 156707                  1          2019.0               6.0
# 157126                  2          2020.0               1.0
# 158206                  0             NaN               NaN
#
#         reviews_per_month  calculated_host_listings_count  availability_365
# 3530                  NaN                               1                 0
# 4937                 0.03                               1                 0
# 13327                1.61                               1               338
# 21944                2.12                               1               365
# 33318                 NaN                               3                 0
# 33319                 NaN                               3                 0
# 33320                 NaN                               3                53
# 63414                1.89                               3               365
# 63807                1.97                               3               359
# 64394                 NaN                               1               179
# 65659                1.23                               3               359
# 106454               0.56                               1               212
# 107621                NaN                               1                 0
# 107960               0.02                               1                 0
# 109079               0.02                               1                 0
# 109666                NaN                               1                 0
# 110099               0.02                               1                 0
# 110508               0.39                               2                 0
# 116016               0.16                               2                 0
# 121925                NaN                               1                 0
# 141592               0.08                               1                89
# 154104               2.29                               1                65
# 154132               2.24                               1               297
# 155162               1.64                               1                57
# 155304               1.71                               1               135
# 155723               1.83                               1                77
# 156707               0.06                               1               365
# 157126               0.18                               1               180
# 158206                NaN                               1               325

# %%
df[df['host_name'].isnull()].index
# Out:
# Int64Index([  3530,   4937,  13327,  21944,  33318,  33319,  33320,  63414,
#              63807,  64394,  65659, 106454, 107621, 107960, 109079, 109666,
#             110099, 110508, 116016, 121925, 141592, 154104, 154132, 155162,
#             155304, 155723, 156707, 157126, 158206],
#            dtype='int64')

# %%
df=df.drop(df[df['host_name'].isnull()].index,axis=0)

# %% [markdown]
# #### Name columns

# %%
df['name']=df['name'].fillna('Unknown')

# %% [markdown]
# #### Bathrooms column

# %%
# Grouping accommodates with bathrooms and bedrooms
df.groupby(['accommodates'])[['bathrooms','bedrooms']].median()
# Out:
#               bathrooms  bedrooms
# accommodates
# 0                   0.0       NaN
# 1                   1.0       1.0
# 2                   1.0       1.0
# 3                   1.0       1.0
# 4                   1.0       1.0
# 5                   1.0       2.0
# 6                   2.0       2.0
# 7                   2.0       3.0
# 8                   2.0       3.0
# 9                   2.0       3.0
# 10                  3.0       4.0
# 11                  2.5       4.0
# 12                  3.0       4.0
# 13                  3.0       4.0
# 14                  3.5       5.0
# 15                  3.0       4.0
# 16                  4.0       6.0

# %%
# Replacing null values for bathrooms
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==0), 'bathrooms']=0
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==1), 'bathrooms']=1
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==2), 'bathrooms']=1
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==3), 'bathrooms']=1
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==4), 'bathrooms']=1
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==5), 'bathrooms']=1
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==6), 'bathrooms']=2
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==7), 'bathrooms']=2
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==8), 'bathrooms']=2
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==9), 'bathrooms']=2
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==10), 'bathrooms']=3
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==11), 'bathrooms']=3
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==12), 'bathrooms']=3
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==13), 'bathrooms']=3
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==14), 'bathrooms']=3.5
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==15), 'bathrooms']=3.5
df.loc[(df['bathrooms'].isnull()) & (df['accommodates']==16), 'bathrooms']=4

# %% [markdown]
# #### Bedrooms Columns

# %%
# Replacing null values for bedrooms
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==0), 'bedrooms']=0
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==1), 'bedrooms']=1
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==2), 'bedrooms']=1
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==3), 'bedrooms']=1
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==4), 'bedrooms']=1
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==5), 'bedrooms']=2
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==6), 'bedrooms']=2
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==7), 'bedrooms']=3
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==8), 'bedrooms']=3
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==9), 'bedrooms']=3
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==10), 'bedrooms']=4
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==11), 'bedrooms']=4
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==12), 'bedrooms']=4
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==13), 'bedrooms']=4
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==14), 'bedrooms']=5
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==15), 'bedrooms']=5
df.loc[(df['bedrooms'].isnull()) & (df['accommodates']==16), 'bedrooms']=6

# %% [markdown]
# #### beds columns

# %%
df.groupby(['bedrooms'])[['beds']].median().values.T
# Out:
# array([[ 0. ,  1. ,  2. ,  4. ,  5. ,  6. ,  7. ,  9. , 12. , 12. , 14. ,
#         18. , 16.5, 19. , 20.5, 11. , 32. , 30. , 29. ,  8.5, 50. , 51. ,
#         66. , 50. ]])

# %%
# Replacing null values for beds
df.loc[(df['beds'].isnull()) & (df['bedrooms']==0), 'beds']=0
df.loc[(df['beds'].isnull()) & (df['bedrooms']==1), 'beds']=1
df.loc[(df['beds'].isnull()) & (df['bedrooms']==2), 'beds']=2
df.loc[(df['beds'].isnull()) & (df['bedrooms']==3), 'beds']=4
df.loc[(df['beds'].isnull()) & (df['bedrooms']==4), 'beds']=5
df.loc[(df['beds'].isnull()) & (df['bedrooms']==5), 'beds']=6
df.loc[(df['beds'].isnull()) & (df['bedrooms']==6), 'beds']=7
df.loc[(df['beds'].isnull()) & (df['bedrooms']==7), 'beds']=9
df.loc[(df['beds'].isnull()) & (df['bedrooms']==8), 'beds']=12
df.loc[(df['beds'].isnull()) & (df['bedrooms']==9), 'beds']=12
df.loc[(df['beds'].isnull()) & (df['bedrooms']==10), 'beds']=14
df.loc[(df['beds'].isnull()) & (df['bedrooms']==11), 'beds']=18
df.loc[(df['beds'].isnull()) & (df['bedrooms']==12), 'beds']=18
df.loc[(df['beds'].isnull()) & (df['bedrooms']==13), 'beds']=19
df.loc[(df['beds'].isnull()) & (df['bedrooms']==14), 'beds']=20.5
df.loc[(df['beds'].isnull()) & (df['bedrooms']==15), 'beds']=20.5
df.loc[(df['beds'].isnull()) & (df['bedrooms']==16), 'beds']=32
df.loc[(df['beds'].isnull()) & (df['bedrooms']==17), 'beds']=32
df.loc[(df['beds'].isnull()) & (df['bedrooms']==18), 'beds']=32
df.loc[(df['beds'].isnull()) & (df['bedrooms']==21), 'beds']=50
df.loc[(df['beds'].isnull()) & (df['bedrooms']==22), 'beds']=50
df.loc[(df['beds'].isnull()) & (df['bedrooms']==27), 'beds']=51
df.loc[(df['beds'].isnull()) & (df['bedrooms']==37), 'beds']=66
df.loc[(df['beds'].isnull()) & (df['bedrooms']==50), 'beds']=66

# %% [markdown]
# #### reviews_per_month column

# %%
df.reviews_per_month=df.reviews_per_month.fillna(0)

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_since_yr                         0
# host_since_mnth                       0
# host_id                               0
# host_name                             0
# host_is_superhost                     0
# host_identity_verified                0
# instant_bookable                      0
# accommodates                          0
# amenities                             0
# State                                 0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# property_type                         0
# room_type                             0
# bathrooms                             0
# bedrooms                              0
# beds                                  0
# price                                 0
# minimum_nights                        0
# maximum_nights                        0
# number_of_reviews                     0
# last_review_yr                    36547
# last_review_mnth                  36547
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## Price noice values removing

# %%
df[df['price']==0].index
# Out:
# Int64Index([ 23919,  24964,  25373,  25374,  25424,  25689,  25733,  25985,
#              39044,  54472,  61874,  91455, 132785, 133893, 134151, 134152,
#             134153, 134154, 134155, 134156, 134157, 134315, 134346, 134347,
#             134419, 134420, 134471, 134970, 135185, 135249, 135436, 135497,
#             135499, 137299, 138940, 152939],
#            dtype='int64')

# %%
df=df.drop(index=[ 23919,  24964,  25373,  25374,  25424,  25689,  25733,  25985,
             39044,  54472,  61874,  91455, 132785, 133893, 134151, 134152,
            134153, 134154, 134155, 134156, 134157, 134315, 134346, 134347,
            134419, 134420, 134471, 134970, 135185, 135249, 135436, 135497,
            135499, 137299, 138940, 152939], axis=0)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Creating a review_category column

# %%
df.head(1)
# Out:
#     id                                                name  host_since_yr  \
# 0  109  Amazing bright elegant condo park front *UPGRADED*         2008.0
#
#    host_since_mnth  host_id host_name host_is_superhost  \
# 0              6.0      521     Paolo                 f
#
#   host_identity_verified instant_bookable  accommodates  \
# 0                      t                f             6
#
#                                                                                                                                                                                                                                                                                amenities  \
# 0  [0.002431751729728165, 0.010074400023159541, 0.1037547404684017, 0.034884057551457605, 0.005355643690472744, 0.04464001389572417, 0.03384187823871696, 0.16640129693425584, 0.007729496569493096, 0.058390990938829865, 0.2101438786440089, 0.24375416147989462, 0.15021856816142198]
#
#         State neighbourhood_group neighbourhood  latitude  longitude  \
# 0  California         Los Angeles   Culver City  33.98209 -118.38494
#
#   property_type        room_type  bathrooms  bedrooms  beds  price  \
# 0   condominium  Entire home/apt        2.0       2.0   3.0    115
#
#    minimum_nights  maximum_nights  number_of_reviews  last_review_yr  \
# 0              30             730                  2          2016.0
#
#    last_review_mnth  reviews_per_month  calculated_host_listings_count  \
# 0               5.0               0.02                               1
#
#    availability_365 review_category  host_months  host_rank  amenities_score  \
# 0               216          Recent        138.0  Long Term         1.071621
#
#    amenities_count Region neighbourhood_state  neighborhood_market  \
# 0               13   West                  CA                118.0
#
#    property_rate property_budget
# 0          173.0             Low

# %%
df['review_category']=df['last_review_yr'].apply(lambda i: 'Recent' if i in range(2016,2021) else 'Old' if i in range(2010,2016) else 'Unknown' )

# %% [markdown]
# ### Creating a host_months column

# %%
df['host_since_yr'].unique()
# Out:
# array([2008., 2009., 2010., 2017., 2015., 2011., 2012., 2013., 2014.,
#        2018., 2016., 2020., 2019.])

# %%
df['host_months']=(2020-df['host_since_yr'])*12-df['host_since_mnth']
df.loc[(df['host_months']<0),'host_months']=12+df['host_months']

# %% [markdown]
# ### Creating a host_rank column

# %%
df['host_rank']=pd.cut(df['host_since_yr'],3,labels=['Long Term','Middle Term','Novice'])

# %%
df[['host_since_yr','host_rank']]
# Out:
#         host_since_yr    host_rank
# 0              2008.0    Long Term
# 1              2008.0    Long Term
# 2              2008.0    Long Term
# 3              2008.0    Long Term
# 4              2009.0    Long Term
# ...               ...          ...
# 158244         2016.0  Middle Term
# 158245         2016.0  Middle Term
# 158246         2016.0  Middle Term
# 158247         2016.0  Middle Term
# 158248         2016.0  Middle Term
#
# [158184 rows x 2 columns]

# %% [markdown]
# ### Creating a amenities_score column

# %%
# ! pip install wordcloud

# %%
# Finding the frequently advertised amenities in the listings provided by all hosts

from wordcloud import WordCloud, STOPWORDS
words=''
stop=set(STOPWORDS)

for i in df['amenities']:
    i=str(i)
    st=i.split()
    for j in range(len(st)):
        st[j]=st[j].lower()
    words+=''.join(st[j])+''
wordcloud=WordCloud(width = 1920, height = 1080,stopwords=stop,collocations=False).generate(words)
plt.imshow(wordcloud)
plt.show()

# %%
worddf=pd.DataFrame(wordcloud.words_.items(),columns=['Word','Importance'])
worddf.head(10)
# Out:
#            Word  Importance
# 0         alarm    1.000000
# 1  refrigerator    0.429928
# 2         stove    0.333034
# 3       allowed    0.297166
# 4       shampoo    0.243754
# 5    essentials    0.210144
# 6         water    0.180355
# 7        basics    0.174449
# 8          iron    0.166401
# 9     workspace    0.155487

# %%
df['amenities']=df['amenities'].str.lower()

# %%
# Removing string which encloses the list

from ast import literal_eval
def safe_literal_eval(node): 
     try:
        return literal_eval(node)
     except ValueError:
        return None
df['amenities']=df['amenities'].apply(safe_literal_eval)

# %%
df['amenities'].isnull().sum()
# Out:
# 1

# %%
df['amenities'].fillna(method='ffill',inplace=True)

# %%
# Creating a dictionary for word and its importances
dictionary={i:j for i,j in zip(worddf['Word'],worddf['Importance'])}
dictionary
# Out:
# {'alarm': 1.0,
#  'refrigerator': 0.42992791593086876,
#  'stove': 0.333034189271343,
#  'allowed': 0.29716585125785255,
#  'shampoo': 0.24375416147989462,
#  'essentials': 0.2101438786440089,
#  'water': 0.1803549199548389,
#  'basics': 0.17444923718264194,
#  'iron': 0.16640129693425584,
#  'workspace': 0.155487363575833,
#  'dryer': 0.15021856816142198,
#  'silverware': 0.12375879338795125,
#  'microwave': 0.11371334279014561,
#  'kitchen': 0.1037547404684017,
#  'parking': 0.10054135425411806,
#  'premises': 0.09498306458616797,
#  'grill': 0.0662941840604464,
#  'tv': 0.058390990938829865,
#  'kit': 0.049995657586196916,
#  'gym': 0.04464001389572417,
#  'entrance': 0.03581043916278262,
#  'heating': 0.034884057551457605,
#  'washer': 0.03384187823871696,
#  'conditioner': 0.0318733173146513,
#  'shades': 0.02698086442984107,
#  'conditioning': 0.024259618446573837,
#  'lockbox': 0.018788177054685464,
#  'maker': 0.018093390846191704,
#  'toys': 0.017948643719422168,
#  'crib': 0.016588020727788554,
#  'tub': 0.015401094288278377,
#  'extinguisher': 0.014966852907969777,
#  'balcony': 0.013808875893813508,
#  'sheet': 0.010942882783776742,
#  'hangers': 0.010074400023159541,
#  'backyard': 0.009871754045682192,
#  'connection': 0.00937961381466578,
#  'room': 0.008945372434357179,
#  'blankets': 0.008018990823032163,
#  'wifi': 0.007729496569493096,
#  'linens': 0.007613698868077469,
#  'dishwasher': 0.007150508062414961,
#  'bathtub': 0.006079379324320412,
#  'keypad': 0.006021480473612599,
#  'dinnerware': 0.006021480473612599,
#  'breakfast': 0.005963581622904785,
#  'access': 0.005616188518657904,
#  'pool': 0.005355643690472744,
#  'waterfront': 0.004921402310164144,
#  'comforts': 0.004197666676316475,
#  'gel': 0.003937121848131314,
#  'door': 0.0035028804678227136,
#  'chair': 0.002923891960744579,
#  'fireplace': 0.0026633471325594187,
#  'elevator': 0.002431751729728165,
#  'fridge': 0.0024028023043742583,
#  'gates': 0.0021712069015430045,
#  'check': 0.0021422574761890975,
#  'cover': 0.0018817126480039372,
#  'charger': 0.001360622991633616,
#  'lock': 0.0009842804620328286,
#  'oven': 0.0009263816113250152,
#  'pit': 0.0009263816113250152,
#  'coffee': 0.0007237356338476681,
#  'unit': 0.0006368873577859479,
#  'fan': 0.0006368873577859479,
#  'space': 0.0006079379324320412,
#  'guards': 0.0006079379324320412,
#  'machine': 0.0005789885070781345,
#  'freezer': 0.0005500390817242278,
#  'staff': 0.0004631908056625076,
#  'system': 0.0004342413803086009,
#  'soap': 0.00037634252960078743,
#  'checkout': 0.00037634252960078743,
#  'seating': 0.0003473931042468807,
#  'building': 0.00031844367889297397,
#  'console': 0.00028949425353906724,
#  'beachfront': 0.0002605448281851605,
#  'office': 0.0002315954028312538,
#  'player': 0.0002315954028312538,
#  'storage': 0.0002315954028312538,
#  'kitchenette': 0.0002315954028312538,
#  'utensils': 0.00020264597747734708,
#  'heater': 0.00020264597747734708,
#  'theater': 0.00017369655212344035,
#  'ski': 0.00017369655212344035,
#  'mbps': 0.00014474712676953362,
#  'home': 0.0001157977014156269,
#  'hdtv': 0.0001157977014156269,
#  'recommendations': 0.0001157977014156269,
#  'netflix': 8.684827606172017e-05,
#  'cameras': 8.684827606172017e-05,
#  'bar': 8.684827606172017e-05,
#  'shower': 8.684827606172017e-05,
#  'chromecast': 8.684827606172017e-05,
#  'table': 8.684827606172017e-05,
#  'library': 5.789885070781345e-05,
#  'loungers': 5.789885070781345e-05,
#  'nearby': 5.789885070781345e-05,
#  'compactor': 5.789885070781345e-05,
#  'cooler': 5.789885070781345e-05,
#  'cable': 5.789885070781345e-05,
#  'events': 5.789885070781345e-05,
#  'sauna': 2.8949425353906726e-05,
#  'technology': 2.8949425353906726e-05,
#  'barbeque': 2.8949425353906726e-05,
#  'vanity': 2.8949425353906726e-05,
#  'amenitiesgrill': 2.8949425353906726e-05,
#  'area': 2.8949425353906726e-05,
#  'backgammon': 2.8949425353906726e-05,
#  'bath': 2.8949425353906726e-05,
#  'video': 2.8949425353906726e-05}

# %%
# words in amentities columns
words=list(df['amenities'])

# words in wordcloud
keep_words=list(worddf['Word'])

# %%
# Retaining the words present wordcloud matching with the amenities column
for i in range(len(words)):
    words[i] = [d for d in words[i] if d in keep_words]

# %%
df['amenities']=words

# %%
df['amenities']=df['amenities'].apply(lambda i: list(map(dictionary.get,i)))

# %%
# Imputing the sum of importances 
df['amenities_score']=df['amenities'].apply(lambda x: sum(x))

# %% [markdown]
# ### Creating a amenities_count column

# %%
# function for finding the length of amenities column
def lenam(x):
    return len(x)

# %%
df['amenities_count']=df['amenities'].apply(lenam)

# %% [markdown]
# ### Creating a Region column

# %%
df['State'].unique()
# Out:
# array(['California', 'Illinois', 'Florida', 'Hawaii', 'Nevada',
#        'New York ', 'Tennessee', 'DC', 'Washington'], dtype=object)

# %% [markdown]
# We divide the states based on the US regions.
# * California - West
# * Illinois - Middle West
# * Florida - South East
# * Hawaii - West
# * Nevada - West
# * New York - North East
# * Tennessee - South East
# * Washington - West
# * DC - West

# %%
state={'California': 'West', 'Illinois': 'Middle West', 'Florida':'South East', 'Hawaii': 'West', 'Nevada': 'West',
       'New York ': 'North East', 'Tennessee':'South East', 'DC':'West', 'Washington':'West'}

# %%
df['Region']=df['State'].map(state)

# %% [markdown]
# ### Creating a neighbourhood state column

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Los Angeles', 'San Diego County', 'San Francisco', 'San Mateo',
#        'Saint Clara County', ' Santa Cruz', 'Chicago', 'Broward County',
#        'Hawaii', 'Kauai', 'Maui', 'Honolulu', 'Clark County', 'Manhattan',
#        'Brooklyn', 'Queens', 'Staten Island', 'Bronx', 'Nashville',
#        'Washington D.C', 'Seattle'], dtype=object)

# %% [markdown]
# Let us divide the Counties into their states
# * 'Los Angeles', CA
# * 'San Diego County', CA
# * 'San Francisco', CA
# * 'San Mateo', CA
# * 'Saint Clara County', CA
# * 'Santa Cruz', CA
# * 'Chicago', IL
# * 'Broward County', FL
# * 'Hawaii', HI
# * 'Kauai', HI
# * 'Maui', HI
# * 'Honolulu', HI
# * 'Clark County', NV
# * 'Manhattan', NY
# * 'Brooklyn', NY
# * 'Queens', NY
# * 'Staten Island', NY
# * 'Bronx', NY
# * 'Nashville', TN
# * 'Washington D.C', DC
# * 'Seattle', WA

# %%
county={'Los Angeles':'CA', 'San Diego County':'CA', 'San Francisco':'CA', 'San Mateo':'CA',
       'Saint Clara County':'CA', ' Santa Cruz':'CA', 'Chicago':'IL', 'Broward County':'FL',
       'Hawaii':'HI', 'Kauai':'HI', 'Maui':'HI', 'Honolulu':'HI', 'Clark County':'NV', 'Manhattan':'NY',
       'Brooklyn':'NY', 'Queens':'NY', 'Staten Island':'NY', 'Bronx':'NY', 'Nashville':'TN',
       'Washington D.C':'DC', 'Seattle':'WA'}

# %%
df['neighbourhood_state']=df['neighbourhood_group'].map(county)

# %% [markdown]
# ### Creating a neighborhood market column

# %%
neighborhood=df.groupby(['neighbourhood'])['price'].median().to_dict()
df['neighborhood_market']=df['neighbourhood'].map(neighborhood)

# %% [markdown]
# ### Creating a property_rate column

# %%
mapped_PT=df.groupby(['property_type'])['price'].median()

# %%
df['property_rate']=df['property_type'].map(mapped_PT)

# %% [markdown]
# ### Creating a property_budget column

# %%
# converting property type to lowercase
df['property_type']=df['property_type'].str.lower()

# %%
df['property_type']=df['property_type'].str.split().str[-1]

# %%
df['property_type'].unique()
# Out:
# array(['condominium', 'apartment', 'house', 'guesthouse', 'loft', 'hotel',
#        'suite', 'bungalow', 'townhouse', 'island', 'hostel', 'villa',
#        'cottage', 'cabin', 'stay', 'camper/rv', 'place', 'aparthotel',
#        'treehouse', 'room', 'castle', 'barn', 'breakfast', 'yurt', 'boat',
#        'tipi', 'campsite', 'tent', 'chalet', 'resort', 'floor', 'train',
#        'home/apt', 'minsu', 'dorm', 'igloo', 'cave', 'particular',
#        'lighthouse', 'home', 'hut', 'houseboat', 'in-law', 'bus',
#        'windmill', 'timeshare', 'lodge'], dtype=object)

# %%
target_price=df.groupby(['property_type'])['price'].mean().to_dict()

# %%
df['property_budget']=df['property_type'].map(target_price)

# %%
df['property_budget']
# Out:
# 0         219.337096
# 1         150.252569
# 2         150.252569
# 3         150.252569
# 4         252.521027
#              ...
# 158244    159.402676
# 158245    159.402676
# 158246    252.521027
# 158247    159.402676
# 158248    219.337096
# Name: property_budget, Length: 158184, dtype: float64

# %%
df['property_budget']=pd.cut(df['property_budget'],bins=4,labels=['Low','Moderate','High','Luxury'],)

# %% [markdown]
# ## Analysis of various columns

# %%
#Finding relationship between Property_type and Room_type

plt.rcParams['figure.figsize']=[75,25]
plt.xticks(rotation=90)
df.groupby(['property_type'])['price'].describe().sort_values(by='mean',ascending=False)['mean'].plot(kind='bar')
plt.show()

# %%
df.groupby(['property_type',"room_type"])['price'].mean().sort_values(ascending=False)
# Out:
# property_type  room_type
# island         Entire home/apt    1500.000000
# villa          Entire home/apt    1438.965350
# igloo          Entire home/apt    1145.000000
# windmill       Entire home/apt     895.000000
# lighthouse     Private room        700.000000
#                                      ...
# stay           Shared room          32.000000
# bungalow       Shared room          30.085714
# train          Private room         30.000000
# cave           Shared room          20.000000
# dorm           Shared room          19.333333
# Name: price, Length: 120, dtype: float64

# %% [markdown]
# * room type is based on property type -- so we can ignore the property type column

# %% [markdown]
# ### Dropping the unnecessary columns

# %%
df_cleaned=df.drop(columns=['name','host_name','id','host_id','State','neighbourhood_group','amenities',
                            "reviews_per_month","host_since_yr","host_since_mnth",'property_type','neighbourhood','last_review_yr','last_review_mnth']).copy(deep=True)

# %%
pd.set_option('display.max_columns',50)
print(df_cleaned.shape)
df_cleaned.head(1)
# Out:
# (158184, 26)
#   host_is_superhost host_identity_verified instant_bookable  accommodates  \
# 0                 f                      t                f             6
#
#    latitude  longitude        room_type  bathrooms  bedrooms  beds  price  \
# 0  33.98209 -118.38494  Entire home/apt        2.0       2.0   3.0    115
#
#    minimum_nights  maximum_nights  number_of_reviews  \
# 0              30             730                  2
#
#    calculated_host_listings_count  availability_365 review_category  \
# 0                               1               216          Recent
#
#    host_months  host_rank  amenities_score  amenities_count Region  \
# 0        138.0  Long Term         1.071621               13   West
#
#   neighbourhood_state  neighborhood_market  property_rate property_budget
# 0                  CA                118.0          173.0             Low

# %% [markdown]
# ## Outliers Checking

# %%
num_cols = df_cleaned.select_dtypes(include=np.number).columns

# %%
iterator=1
plt.rcParams['figure.figsize']=[25,37]
for i in num_cols:
    plt.title(i)
    plt.subplot(10,2,iterator)
    sns.boxplot(df_cleaned[i])
    iterator+=1
plt.tight_layout()
plt.show()

# %%
# IQR method 

q1=df_cleaned.quantile(0.25)
q3=df_cleaned.quantile(0.75)

iqr=q3-q1

ul=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
out_count={}
for i in list(num_cols):
    print(i)
    print(df_cleaned[(df_cleaned[i] > ul[i]) | (df_cleaned[i] < ll[i])][i])
    out_count.update({i:len(df_cleaned[(df_cleaned[i] > ul[i]) | (df_cleaned[i] < ll[i])][i])})
    print()
# Out:
# accommodates
# 107       10
# 124       15
# 177       10
# 247       12
# 300       16
#           ..
# 157419    10
# 157479    12
# 157509    10
# 157615    13
# 157924    16
# Name: accommodates, Length: 7514, dtype: int64
#
# latitude
# 72862    20.040950
# 72863    20.027400
# 72864    19.431190
# 72865    19.564130
# 72868    20.754700
#            ...
# 94472    20.724040
# 94474    20.933380
# 94476    20.938539
# 94481    20.968876
# 94484    19.487739
# Name: latitude, Length: 12192, dtype: float64
#
# longitude
# Series([], Name: longitude, dtype: float64)
#
# bathrooms
# 51        11.0
# 107        6.5
# 124        4.0
# 126       11.0
# 139       11.0
#           ...
# 156013     4.5
# 156133     4.0
# 156706     5.0
# 156871     4.0
# 157924     4.0
# Name: bathrooms, Length: 3579, dtype: float64
#
# bedrooms
# 95        4.0
# 107       6.0
# 124       5.0
# 177       5.0
# 270       5.0
#          ...
# 157780    4.0
# 157887    4.0
# 157924    7.0
# 158110    4.0
# 158216    4.0
# Name: bedrooms, Length: 8721, dtype: float64
#
# beds
# 177        9.0
# 240        7.0
# 300        8.0
# 324       11.0
# 403       15.0
#           ...
# 157218     9.0
# 157409     8.0
# 157479     7.0
# 157615     7.0
# 157924    14.0
# Name: beds, Length: 3767, dtype: float64
#
# price
# 20        425
# 24        438
# 46        900
# 74        417
# 77        395
#          ...
# 157615    407
# 157738    498
# 157887    495
# 157924    472
# 157936    405
# Name: price, Length: 13978, dtype: int64
#
# minimum_nights
# 100       180
# 106       330
# 134        90
# 181        84
# 227       360
#          ...
# 158209     90
# 158210     90
# 158218     90
# 158230     90
# 158237     90
# Name: minimum_nights, Length: 2080, dtype: int64
#
# maximum_nights
# 231             3022
# 865             9033
# 2105           10000
# 2383            3650
# 13189           3000
# 31821          16960
# 32468           9999
# 34115           9999
# 40534          10000
# 42397          10000
# 42545      100000000
# 47525          10000
# 62817           3650
# 94656           9999
# 94716           9999
# 95505           9999
# 95703           5000
# 105589         10000
# 105609         10000
# 108916          6000
# 109027      20000000
# 109074    2147483647
# 110240      20000000
# 117161          3000
# 118003          9999
# 119326          9999
# 119502          9999
# 146521          3365
# 146524          3365
# 146561         10000
# 146799      99999999
# 149339         10000
# 154190         10000
# Name: maximum_nights, dtype: int64
#
# number_of_reviews
# 4         310
# 5         230
# 9         241
# 10        393
# 18        172
#          ...
# 156301    165
# 156320    155
# 156409    164
# 156518    195
# 156524    187
# Name: number_of_reviews, Length: 21593, dtype: int64
#
# calculated_host_listings_count
# 51         20
# 126        20
# 139        20
# 182        41
# 232        19
#          ...
# 158235    350
# 158236    350
# 158237    350
# 158238    350
# 158241    350
# Name: calculated_host_listings_count, Length: 27552, dtype: int64
#
# availability_365
# Series([], Name: availability_365, dtype: int64)
#
# host_months
# 0         138.0
# 1         135.0
# 2         135.0
# 3         135.0
# 7         135.0
#           ...
# 153914    136.0
# 154416    134.0
# 154922    131.0
# 156158    134.0
# 156321    136.0
# Name: host_months, Length: 123, dtype: float64
#
# amenities_score
# Series([], Name: amenities_score, dtype: float64)
#
# amenities_count
# Series([], Name: amenities_count, dtype: int64)
#
# neighborhood_market
# 45        779.0
# 60        779.0
# 122       225.5
# 124       387.0
# 142       779.0
#           ...
# 110223    350.0
# 115504    397.5
# 119202    800.0
# 128488    397.5
# 138501    255.0
# Name: neighborhood_market, Length: 11945, dtype: float64
#
# property_rate
# 95        775.0
# 124       775.0
# 408       775.0
# 418       775.0
# 485       775.0
#           ...
# 151140    775.0
# 152057    775.0
# 154958    775.0
# 156172    775.0
# 156508    775.0
# Name: property_rate, Length: 1481, dtype: float64

# %%
# Count of outliers present in each column
out_count
# Out:
# {'accommodates': 7514,
#  'latitude': 12192,
#  'longitude': 0,
#  'bathrooms': 3579,
#  'bedrooms': 8721,
#  'beds': 3767,
#  'price': 13978,
#  'minimum_nights': 2080,
#  'maximum_nights': 33,
#  'number_of_reviews': 21593,
#  'calculated_host_listings_count': 27552,
#  'availability_365': 0,
#  'host_months': 123,
#  'amenities_score': 0,
#  'amenities_count': 0,
#  'neighborhood_market': 11945,
#  'property_rate': 1481}

# %% [markdown]
# ## Scaling columns

# %%
df_sc=df_cleaned.copy(deep=True)

# %%
df_sc.isnull().sum()
# Out:
# host_is_superhost                 0
# host_identity_verified            0
# instant_bookable                  0
# accommodates                      0
# latitude                          0
# longitude                         0
# room_type                         0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# review_category                   0
# host_months                       0
# host_rank                         0
# amenities_score                   0
# amenities_count                   0
# Region                            0
# neighbourhood_state               0
# neighborhood_market               0
# property_rate                     0
# property_budget                   0
# dtype: int64

# %%
# Numerical columns
df_sc.select_dtypes(include=np.number).columns
# Out:
# Index(['accommodates', 'latitude', 'longitude', 'bathrooms', 'bedrooms',
#        'beds', 'price', 'minimum_nights', 'maximum_nights',
#        'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365', 'host_months', 'amenities_score', 'amenities_count',
#        'neighborhood_market', 'property_rate'],
#       dtype='object')

# %%
ncols=['accommodates','bathrooms',
       'bedrooms', 'beds', 'minimum_nights', 'maximum_nights',
       'number_of_reviews', 'calculated_host_listings_count',
       'availability_365', 'host_months']

# %%
# Scaling the needed colums with MinMax Scaler
from sklearn.preprocessing import MinMaxScaler

mm=MinMaxScaler()

for i in ncols:
    df_sc[i] = mm.fit_transform(df_sc[[i]])

# %%
df_sc.head(2)
# Out:
#   host_is_superhost host_identity_verified instant_bookable  accommodates  \
# 0                 f                      t                f        0.3750
# 1                 t                      t                t        0.0625
#
#    latitude  longitude        room_type  bathrooms  bedrooms      beds  price  \
# 0  33.98209 -118.38494  Entire home/apt       0.04      0.04  0.045455    115
# 1  34.09768 -118.34602     Private room       0.03      0.02  0.015152     71
#
#    minimum_nights  maximum_nights  number_of_reviews  \
# 0    2.900000e-07    3.399327e-07           0.001096
# 1    2.900000e-07    1.704320e-07           0.014795
#
#    calculated_host_listings_count  availability_365 review_category  \
# 0                        0.000000          0.591781          Recent
# 1                        0.002597          0.986301          Recent
#
#    host_months  host_rank  amenities_score  amenities_count Region  \
# 0     0.971831  Long Term         1.071621               13   West
# 1     0.950704  Long Term         1.898590               17   West
#
#   neighbourhood_state  neighborhood_market  property_rate property_budget
# 0                  CA                118.0          173.0             Low
# 1                  CA                117.0           65.0             Low

# %% [markdown]
# ## Statistical Analysis

# %%
num_cols = df_sc.select_dtypes(include = np.number).columns
num_cols
# Out:
# Index(['accommodates', 'latitude', 'longitude', 'bathrooms', 'bedrooms',
#        'beds', 'price', 'minimum_nights', 'maximum_nights',
#        'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365', 'host_months', 'amenities_score', 'amenities_count',
#        'neighborhood_market', 'property_rate'],
#       dtype='object')

# %% [markdown]
# ### Performing ttest for Numerical columns

# %%
from scipy import stats

# %%
# Get important features from the numerical variables
significant_features=[]
for i in num_cols:
    if i !="price":
        if stats.ttest_ind(df[i], df['price'])[1] < 0.05:
            print(i, stats.ttest_ind(df[i], df['price'])[1])
            significant_features.append(i)
        else:
             print(i, stats.ttest_ind(df[i], df['price'])[1])
# Out:
# accommodates 0.0
# latitude 0.0
# longitude 0.0
# bathrooms 0.0
# bedrooms 0.0
# beds 0.0
# minimum_nights 0.4846115718214714
# maximum_nights 0.25601766258318526
# number_of_reviews 0.0
# calculated_host_listings_count 0.0
# availability_365 3.584388599256184e-92
# host_months 0.0
# amenities_score 0.0
# amenities_count 0.0
# neighborhood_market 0.0
# property_rate 0.0

# %%
print('Significant features :',significant_features)
# Out:
# Significant features : ['accommodates', 'latitude', 'longitude', 'bathrooms', 'bedrooms', 'beds', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365', 'host_months', 'amenities_score', 'amenities_count', 'neighborhood_market', 'property_rate']

# %% [markdown]
# ### Performing Anova test for Categorical columns

# %%
cat_cols
# Out:
# Index(['name', 'host_name', 'host_since', 'host_is_superhost',
#        'host_identity_verified', 'instant_bookable', 'amenities', 'State',
#        'neighbourhood_group', 'neighbourhood', 'property_type', 'room_type',
#        'last_review'],
#       dtype='object')

# %%
from statsmodels.formula.api  import ols
import statsmodels.api as sm
mod = ols('price ~ room_type', data = df).fit()
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)

#Since Pvalue is lesser than 0.05 , room_type is a significant variable
# Out:
#                  sum_sq        df           F  PR(>F)
# room_type  7.312867e+08       3.0  992.440899     0.0
# Residual   3.885200e+10  158180.0         NaN     NaN

# %%
from statsmodels.formula.api  import ols
import statsmodels.api as sm
mod = ols('price ~ State', data = df).fit()
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)

#Since Pvalue is lesser than 0.05 , State is a significant variable
# Out:
#                 sum_sq        df           F  PR(>F)
# State     4.103636e+08       8.0  207.124149     0.0
# Residual  3.917292e+10  158175.0         NaN     NaN

# %%
from statsmodels.formula.api  import ols
import statsmodels.api as sm
mod = ols('price ~ neighbourhood_group', data = df).fit()
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)

#Since Pvalue is lesser than 0.05 , neighbourhood_group is a significant variable
# Out:
#                            sum_sq        df           F  PR(>F)
# neighbourhood_group  5.167389e+08      20.0  104.602247     0.0
# Residual             3.906655e+10  158163.0         NaN     NaN

# %%
from statsmodels.formula.api  import ols
import statsmodels.api as sm
mod = ols('price ~ instant_bookable', data = df).fit()
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)

#Since Pvalue is lesser than 0.05 , instant_bookable is a significant variable
# Out:
#                         sum_sq        df         F    PR(>F)
# instant_bookable  1.992860e+06       1.0  7.964233  0.004772
# Residual          3.958129e+10  158182.0       NaN       NaN

# %%
from statsmodels.formula.api  import ols
import statsmodels.api as sm
mod = ols('price ~ host_is_superhost', data = df).fit()
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)

#Since Pvalue is lesser than 0.05 , host_is_superhost is a significant variable
# Out:
#                          sum_sq        df          F        PR(>F)
# host_is_superhost  6.849973e+06       1.0  27.378474  1.674955e-07
# Residual           3.957643e+10  158182.0        NaN           NaN

# %% [markdown]
# # Encoding

# %%
df_sc.select_dtypes(exclude=np.number).columns
# Out:
# Index(['host_is_superhost', 'host_identity_verified', 'instant_bookable',
#        'room_type', 'review_category', 'host_rank', 'Region',
#        'neighbourhood_state', 'property_budget'],
#       dtype='object')

# %%
print('No of unique values in host_is_superhost : ',df['host_is_superhost'].nunique())
print('No of unique values in host_identity_verified: ',df['host_identity_verified'].nunique())
print('No of unique values in instant_bookable: ',df['instant_bookable'].nunique())
df[["host_is_superhost","host_identity_verified","instant_bookable"]].head()
# Label encoding - since there are only two levels present in these columns
# Out:
# No of unique values in host_is_superhost :  2
# No of unique values in host_identity_verified:  2
# No of unique values in instant_bookable:  2
#   host_is_superhost host_identity_verified instant_bookable
# 0                 f                      t                f
# 1                 t                      t                t
# 2                 f                      t                f
# 3                 f                      t                t
# 4                 t                      t                f

# %%
tfd={'t':1,'f':0}

# %%
df_sc['host_is_superhost']=df_sc['host_is_superhost'].map(tfd)
df_sc['host_identity_verified']=df_sc['host_identity_verified'].map(tfd)
df_sc['instant_bookable']=df_sc['instant_bookable'].map(tfd)

# %%
df_sc.select_dtypes(exclude=np.number).columns
# Out:
# Index(['room_type', 'review_category', 'host_rank', 'Region',
#        'neighbourhood_state', 'property_budget'],
#       dtype='object')

# %%
# One-Hot encoding for other features
final_df = pd.get_dummies(df_sc,drop_first=True)

# %%
final_df.shape
# Out:
# (158184, 41)

# %%
final_df.head()
# Out:
#    host_is_superhost  host_identity_verified  instant_bookable  accommodates  \
# 0                  0                       1                 0        0.3750
# 1                  1                       1                 1        0.0625
# 2                  0                       1                 0        0.0625
# 3                  0                       1                 1        0.1250
# 4                  1                       1                 0        0.1250
#
#    latitude  longitude  bathrooms  bedrooms      beds  price  minimum_nights  \
# 0  33.98209 -118.38494       0.04      0.04  0.045455    115    2.900000e-07
# 1  34.09768 -118.34602       0.03      0.02  0.015152     71    2.900000e-07
# 2  34.00475 -118.48127       0.02      0.02  0.015152    155    0.000000e+00
# 3  33.87619 -118.11397       0.02      0.02  0.015152     50    2.900000e-07
# 4  33.98750 -118.43200       0.02      0.02  0.015152     60    2.900000e-07
#
#    maximum_nights  number_of_reviews  calculated_host_listings_count  \
# 0    3.399327e-07           0.001096                        0.000000
# 1    1.704320e-07           0.014795                        0.002597
# 2    8.381903e-08           0.011507                        0.002597
# 3    3.399327e-07           0.000000                        0.000000
# 4    5.238689e-07           0.169863                        0.010390
#
#    availability_365  host_months  amenities_score  amenities_count  \
# 0          0.591781     0.971831         1.071621               13
# 1          0.986301     0.950704         1.898590               17
# 2          0.923288     0.950704         1.338969               11
# 3          0.000000     0.950704         1.215326               10
# 4          0.923288     0.894366         1.029152               10
#
#    neighborhood_market  property_rate  room_type_Hotel room  \
# 0                118.0          173.0                     0
# 1                117.0           65.0                     0
# 2                138.0           65.0                     0
# 3                 70.0          129.0                     0
# 4                122.5           65.0                     0
#
#    room_type_Private room  room_type_Shared room  review_category_Recent  \
# 0                       0                      0                       1
# 1                       1                      0                       1
# 2                       1                      0                       1
# 3                       0                      0                       0
# 4                       1                      0                       1
#
#    review_category_Unknown  host_rank_Middle Term  host_rank_Novice  \
# 0                        0                      0                 0
# 1                        0                      0                 0
# 2                        0                      0                 0
# 3                        1                      0                 0
# 4                        0                      0                 0
#
#    Region_North East  Region_South East  Region_West  neighbourhood_state_DC  \
# 0                  0                  0            1                       0
# 1                  0                  0            1                       0
# 2                  0                  0            1                       0
# 3                  0                  0            1                       0
# 4                  0                  0            1                       0
#
#    neighbourhood_state_FL  neighbourhood_state_HI  neighbourhood_state_IL  \
# 0                       0                       0                       0
# 1                       0                       0                       0
# 2                       0                       0                       0
# 3                       0                       0                       0
# 4                       0                       0                       0
#
#    neighbourhood_state_NV  neighbourhood_state_NY  neighbourhood_state_TN  \
# 0                       0                       0                       0
# 1                       0                       0                       0
# 2                       0                       0                       0
# 3                       0                       0                       0
# 4                       0                       0                       0
#
#    neighbourhood_state_WA  property_budget_Moderate  property_budget_High  \
# 0                       0                         0                     0
# 1                       0                         0                     0
# 2                       0                         0                     0
# 3                       0                         0                     0
# 4                       0                         0                     0
#
#    property_budget_Luxury
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# ## Base Model

# %% [markdown]
# ### Linear statstical model

# %%
import statsmodels.api as sma

X=final_df.drop('price',axis=1)
y=final_df['price']

newx = sma.add_constant(X)

model_lr = sma.OLS(y,newx).fit()

model_lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     1031.
# Date:                Wed, 21 Dec 2022   Prob (F-statistic):               0.00
# Time:                        19:31:49   Log-Likelihood:            -1.1905e+06
# No. Observations:              158184   AIC:                         2.381e+06
# Df Residuals:                  158146   BIC:                         2.381e+06
# Df Model:                          37
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            504.3721    190.388      2.649      0.008     131.216     877.528
# host_is_superhost                  4.0946      2.574      1.591      0.112      -0.950       9.139
# host_identity_verified            -7.8400      2.898     -2.705      0.007     -13.520      -2.160
# instant_bookable                  -6.3672      2.435     -2.615      0.009     -11.140      -1.595
# accommodates                     121.6995     14.498      8.394      0.000      93.284     150.115
# latitude                          31.1376      5.251      5.930      0.000      20.847      41.429
# longitude                         21.5939      4.638      4.656      0.000      12.503      30.684
# bathrooms                       5593.4240     98.997     56.501      0.000    5399.392    5787.456
# bedrooms                        3207.2856    119.040     26.943      0.000    2973.969    3440.602
# beds                            -853.6029     76.755    -11.121      0.000   -1004.040    -703.165
# minimum_nights                   -73.4765    449.599     -0.163      0.870    -954.680     807.727
# maximum_nights                   -51.4786    448.671     -0.115      0.909    -930.865     827.908
# number_of_reviews                 20.9220     10.586      1.976      0.048       0.174      41.670
# calculated_host_listings_count   -13.1759     10.101     -1.304      0.192     -32.973       6.621
# availability_365                  -9.5560      3.094     -3.089      0.002     -15.620      -3.492
# host_months                       -7.6312     13.430     -0.568      0.570     -33.953      18.691
# amenities_score                  -47.5689      5.392     -8.822      0.000     -58.137     -37.000
# amenities_count                    2.1467      0.733      2.930      0.003       0.711       3.583
# neighborhood_market                1.0513      0.020     53.294      0.000       1.013       1.090
# property_rate                      0.4630      0.024     19.214      0.000       0.416       0.510
# room_type_Hotel room              30.6182     13.700      2.235      0.025       3.766      57.471
# room_type_Private room            -7.0386      3.621     -1.944      0.052     -14.135       0.058
# room_type_Shared room            -62.6474      9.149     -6.848      0.000     -80.578     -44.716
# review_category_Recent           -13.7157     11.016     -1.245      0.213     -35.307       7.875
# review_category_Unknown           73.0315     11.175      6.535      0.000      51.129      94.934
# host_rank_Middle Term             -6.4389      5.226     -1.232      0.218     -16.682       3.804
# host_rank_Novice                 -10.7126      8.424     -1.272      0.203     -27.223       5.798
# Region_North East               -179.3975     28.062     -6.393      0.000    -234.398    -124.397
# Region_South East                 31.1106     26.255      1.185      0.236     -20.348      82.569
# Region_West                      785.5808    186.056      4.222      0.000     420.915    1150.246
# neighbourhood_state_DC         -1029.5720    216.892     -4.747      0.000   -1454.677    -604.467
# neighbourhood_state_FL           136.2296     24.275      5.612      0.000      88.650     183.809
# neighbourhood_state_HI          1213.5415    247.812      4.897      0.000     727.836    1699.247
# neighbourhood_state_IL          -132.9218     15.583     -8.530      0.000    -163.465    -102.379
# neighbourhood_state_NV          -223.2749     26.099     -8.555      0.000    -274.428    -172.122
# neighbourhood_state_NY          -179.3975     28.062     -6.393      0.000    -234.398    -124.397
# neighbourhood_state_TN          -105.1190      8.026    -13.098      0.000    -120.849     -89.389
# neighbourhood_state_WA          -355.3404     53.583     -6.632      0.000    -460.362    -250.319
# property_budget_Moderate         106.7030      8.071     13.221      0.000      90.884     122.522
# property_budget_High             301.7941     54.126      5.576      0.000     195.709     407.879
# property_budget_Luxury           343.2096     14.577     23.545      0.000     314.640     371.780
# ==============================================================================
# Omnibus:                   395433.491   Durbin-Watson:                   1.657
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       8850020090.585
# Skew:                          27.362   Prob(JB):                         0.00
# Kurtosis:                    1160.475   Cond. No.                     1.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.86e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Linear Regression Assumptions:
# * Linearity
# * Normality
# * Heteroscedasticity
# * Autocorrelation of errors
# * Multicollinearity

# %% [markdown]
# ### Linearity
#
# * Ho: Model is linear
#
# * H1: Model is not linear

# %%
from statsmodels.stats.diagnostic import linear_rainbow
fstat,pval=linear_rainbow(model_lr)
pval>0.05
# Out:
# True

# %% [markdown]
# **Null hypothesis is accepted that model is linear.**

# %% [markdown]
# ### Normality
#
# * Ho: Data is normal
#
# * H1: Data is not normal

# %%
fstat,pval=stats.jarque_bera(model_lr.resid)
pval>0.05
# Out:
# False

# %% [markdown]
# **Null hypothesis is rejected so the data is not normal.**

# %% [markdown]
# ### Heteroscedasticity
# * Ho: Data has equal variance (Not heteroscedastic)
#
# * H1: Data has unequal variance (Heteroscedastic)

# %%
import statsmodels.stats.api as ssa

# %%
test,pval,f_stat,fp=ssa.het_breuschpagan(model_lr.resid, model_lr.model.exog)
pval>0.05
# Out:
# False

# %% [markdown]
# **Null hypothesis is rejected so the data has heteroscedasticity.**

# %% [markdown]
# ### Multi Collinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=[]
for i in range(X.shape[1]):
    vif.append(variance_inflation_factor(X.values,i))

vif=pd.DataFrame({'Variables':X.columns, 'VIF':vif})
vif
# Out:
#                          Variables           VIF
# 0                host_is_superhost  1.152666e+00
# 1           host_identity_verified  1.047704e+00
# 2                 instant_bookable  1.145389e+00
# 3                     accommodates  4.502991e+00
# 4                         latitude  1.041073e+03
# 5                        longitude  1.319802e+04
# 6                        bathrooms  2.369738e+00
# 7                         bedrooms  4.681389e+00
# 8                             beds  3.383386e+00
# 9                   minimum_nights  1.002402e+00
# 10                  maximum_nights  1.002772e+00
# 11               number_of_reviews  2.041739e+00
# 12  calculated_host_listings_count  1.290826e+00
# 13                availability_365  1.091565e+00
# 14                     host_months  5.816241e+00
# 15                 amenities_score  6.451715e+00
# 16                 amenities_count  6.710388e+00
# 17             neighborhood_market  1.358528e+00
# 18                   property_rate  3.645203e+00
# 19            room_type_Hotel room  1.228482e+00
# 20          room_type_Private room  2.122779e+00
# 21           room_type_Shared room  1.205152e+00
# 22          review_category_Recent  1.745864e+01
# 23         review_category_Unknown  1.739076e+01
# 24           host_rank_Middle Term  5.341400e+00
# 25                host_rank_Novice  1.267723e+01
# 26               Region_North East           inf
# 27               Region_South East           inf
# 28                     Region_West  6.922101e+04
# 29          neighbourhood_state_DC  1.646385e+03
# 30          neighbourhood_state_FL           inf
# 31          neighbourhood_state_HI  5.684627e+03
# 32          neighbourhood_state_IL  1.221396e+03
# 33          neighbourhood_state_NV  2.913754e+01
# 34          neighbourhood_state_NY           inf
# 35          neighbourhood_state_TN           inf
# 36          neighbourhood_state_WA  5.992257e+01
# 37        property_budget_Moderate  1.425663e+00
# 38            property_budget_High  1.001980e+00
# 39          property_budget_Luxury  2.051974e+00

# %% [markdown]
# Region , neighbourhood states , review category, latitude , longitude all columns are having multi collinearity

# %% [markdown]
# ### Autocorrelation of errors

# %%
from statsmodels.stats.stattools import durbin_watson
durbin_watson(model_lr.resid)
# Out:
# 1.6567433184742706

# %% [markdown]
# **This is an ideal value denoting there is no autocorrelation of errors.**

# %% [markdown]
# ## Splitting the data

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest = train_test_split(X,y,train_size=.8,random_state=42)

print(xtrain.shape,xtest.shape)
print(ytrain.shape,ytest.shape)
# Out:
# (126547, 40) (31637, 40)
# (126547,) (31637,)

# %%
# !pip install mlxtend

# %% [markdown]
# ### Feature Selection

# %%
# Forward selection
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from mlxtend.feature_selection import SequentialFeatureSelector
sfs=SequentialFeatureSelector(estimator=lr,n_jobs=-1,k_features='best',cv=5,verbose=2,scoring='r2')

# %%
sfs.fit(xtrain,ytrain)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   11.0s finished
#
# [2022-12-20 22:07:51] Features: 1/40 -- score: 0.12554582758113614[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  39 out of  39 | elapsed:    2.2s finished
#
# [2022-12-20 22:07:53] Features: 2/40 -- score: 0.15871858298996985[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 out of  38 | elapsed:    2.8s finished
#
# [2022-12-20 22:07:56] Features: 3/40 -- score: 0.17426150591494644[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 out of  37 | elapsed:    4.2s finished
#
# [2022-12-20 22:08:01] Features: 4/40 -- score: 0.18106452392785927[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    3.9s finished
#
# [2022-12-20 22:08:05] Features: 5/40 -- score: 0.18575442787818144[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    5.3s finished
#
# [2022-12-20 22:08:10] Features: 6/40 -- score: 0.18980865170863487[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.6s finished
#
# [2022-12-20 22:08:16] Features: 7/40 -- score: 0.1917764737270669[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.0s finished
#
# [2022-12-20 22:08:23] Features: 8/40 -- score: 0.19323050887425766[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.5s finished
#
# [2022-12-20 22:08:29] Features: 9/40 -- score: 0.19437891063112137[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    7.5s finished
#
# [2022-12-20 22:08:37] Features: 10/40 -- score: 0.19552774780596108[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    8.0s finished
#
# [2022-12-20 22:08:46] Features: 11/40 -- score: 0.19643237799284002[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    8.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    8.6s finished
#
# [2022-12-20 22:08:55] Features: 12/40 -- score: 0.19700044762307017[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    9.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    9.0s finished
#
# [2022-12-20 22:09:04] Features: 13/40 -- score: 0.19729140304267018[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:   10.4s finished
#
# [2022-12-20 22:09:15] Features: 14/40 -- score: 0.19752902759766994[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:   11.6s finished
#
# [2022-12-20 22:09:27] Features: 15/40 -- score: 0.1977354969881002[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:   10.3s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   10.3s finished
#
# [2022-12-20 22:09:37] Features: 16/40 -- score: 0.19791209091950154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:   11.3s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:   11.4s finished
#
# [2022-12-20 22:09:49] Features: 17/40 -- score: 0.19808181909666484[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:   12.3s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:   12.8s finished
#
# [2022-12-20 22:10:02] Features: 18/40 -- score: 0.19820740150226585[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:   14.6s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:   15.0s finished
#
# [2022-12-20 22:10:18] Features: 19/40 -- score: 0.19830703507545502[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   13.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   14.0s finished
#
# [2022-12-20 22:10:33] Features: 20/40 -- score: 0.1983690803318869[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   12.1s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.8s finished
#
# [2022-12-20 22:10:47] Features: 21/40 -- score: 0.19842730465109365[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   11.7s remaining:    4.1s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   13.4s finished
#
# [2022-12-20 22:11:01] Features: 22/40 -- score: 0.19846933072648792[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:   10.4s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   11.9s finished
#
# [2022-12-20 22:11:13] Features: 23/40 -- score: 0.19850370694140218[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:   11.2s remaining:    6.1s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:   12.4s finished
#
# [2022-12-20 22:11:26] Features: 24/40 -- score: 0.19852574641859258[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:   10.8s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:   12.9s finished
#
# [2022-12-20 22:11:39] Features: 25/40 -- score: 0.19853305038977034[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    6.6s remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   12.4s finished
#
# [2022-12-20 22:11:51] Features: 26/40 -- score: 0.1985315721796416[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    7.1s remaining:    7.1s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:   12.0s finished
#
# [2022-12-20 22:12:04] Features: 27/40 -- score: 0.19853211476332433[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  13 | elapsed:    7.5s remaining:   12.1s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:   12.0s finished
#
# [2022-12-20 22:12:16] Features: 28/40 -- score: 0.19852941256565423[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  12 | elapsed:    7.1s remaining:   14.3s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:   10.7s finished
#
# [2022-12-20 22:12:27] Features: 29/40 -- score: 0.19852189927501357[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  11 | elapsed:    6.8s remaining:   30.9s
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    7.3s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:   10.0s finished
#
# [2022-12-20 22:12:37] Features: 30/40 -- score: 0.1985068950726159[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    7.5s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    9.3s finished
#
# [2022-12-20 22:12:47] Features: 31/40 -- score: 0.19848987190358772[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    7.6s remaining:    9.5s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    9.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    9.4s finished
#
# [2022-12-20 22:12:57] Features: 32/40 -- score: 0.19848398161527014[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    8.9s remaining:   14.9s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    9.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    9.6s finished
#
# [2022-12-20 22:13:07] Features: 33/40 -- score: 0.19845220010305273[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    7.9s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    8.0s finished
#
# [2022-12-20 22:13:15] Features: 34/40 -- score: 0.1984193910377265[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    6.2s remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    6.3s finished
#
# [2022-12-20 22:13:22] Features: 35/40 -- score: 0.19854533767093413[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    5.3s remaining:    8.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.4s finished
#
# [2022-12-20 22:13:28] Features: 36/40 -- score: 0.19854533767093868[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    4.2s finished
#
# [2022-12-20 22:13:32] Features: 37/40 -- score: 0.19854533767093688[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    4.1s finished
#
# [2022-12-20 22:13:37] Features: 38/40 -- score: 0.19854533767093346[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.1s finished
#
# [2022-12-20 22:13:40] Features: 39/40 -- score: 0.1984377224553524[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.8s finished
#
# [2022-12-20 22:13:42] Features: 40/40 -- score: -7979.47859072076
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=(1, 40),
#                           n_jobs=-1, scoring='r2', verbose=2)

# %%
k_features=list(sfs.k_feature_names_)
len(k_features)
# Out:
# 36

# %%
# Utilizing the features obtained from feature selection
X1 = xtrain.loc[:,k_features]

# %%
# Building model with obtanied features
newx = sma.add_constant(X1)

model_lr = sma.OLS(ytrain,newx).fit()

model_lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.198
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     893.7
# Date:                Tue, 20 Dec 2022   Prob (F-statistic):               0.00
# Time:                        22:13:43   Log-Likelihood:            -9.5101e+05
# No. Observations:              126547   AIC:                         1.902e+06
# Df Residuals:                  126511   BIC:                         1.902e+06
# Df Model:                          35
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            155.5421    155.584      1.000      0.317    -149.400     460.484
# host_is_superhost                  5.8401      2.846      2.052      0.040       0.262      11.418
# host_identity_verified            -7.3007      3.203     -2.279      0.023     -13.579      -1.023
# instant_bookable                  -6.8985      2.692     -2.563      0.010     -12.175      -1.622
# accommodates                     118.3972     15.897      7.448      0.000      87.239     149.555
# latitude                          31.4429      5.810      5.412      0.000      20.056      42.830
# longitude                         21.8390      5.131      4.256      0.000      11.782      31.896
# bathrooms                       5400.4135    108.716     49.675      0.000    5187.333    5613.494
# bedrooms                        3388.9960    130.442     25.981      0.000    3133.333    3644.659
# beds                            -950.9420     84.703    -11.227      0.000   -1116.959    -784.925
# number_of_reviews                 33.1009     11.690      2.831      0.005      10.188      56.014
# calculated_host_listings_count   -22.5881     11.156     -2.025      0.043     -44.454      -0.722
# availability_365                  -7.9821      3.422     -2.332      0.020     -14.690      -1.274
# host_months                      -15.7737     14.849     -1.062      0.288     -44.878      13.331
# amenities_score                  -49.4880      5.953     -8.313      0.000     -61.156     -37.820
# amenities_count                    2.3663      0.809      2.924      0.003       0.780       3.953
# neighborhood_market                1.0805      0.022     49.605      0.000       1.038       1.123
# property_rate                      0.4703      0.027     17.634      0.000       0.418       0.523
# room_type_Hotel room              41.5187     15.265      2.720      0.007      11.600      71.437
# room_type_Private room            -6.3346      4.004     -1.582      0.114     -14.182       1.512
# room_type_Shared room            -59.7898     10.144     -5.894      0.000     -79.671     -39.908
# review_category_Recent           -15.6865     12.195     -1.286      0.198     -39.588       8.215
# review_category_Unknown           72.1337     12.371      5.831      0.000      47.887      96.380
# host_rank_Middle Term             -7.3533      5.779     -1.272      0.203     -18.680       3.973
# host_rank_Novice                 -14.6570      9.311     -1.574      0.115     -32.907       3.593
# Region_South East                274.1649     69.334      3.954      0.000     138.272     410.058
# Region_West                     1156.3523    265.993      4.347      0.000     635.011    1677.693
# neighbourhood_state_DC         -1041.0120    239.958     -4.338      0.000   -1511.325    -570.699
# neighbourhood_state_FL           257.2426     47.316      5.437      0.000     164.504     349.981
# neighbourhood_state_HI          1220.7727    274.145      4.453      0.000     683.452    1758.093
# neighbourhood_state_IL           230.0206     64.070      3.590      0.000     104.444     355.597
# neighbourhood_state_NV          -223.6289     28.859     -7.749      0.000    -280.192    -167.066
# neighbourhood_state_TN            16.9223     23.301      0.726      0.468     -28.747      62.591
# neighbourhood_state_WA          -359.0025     59.284     -6.056      0.000    -475.198    -242.807
# property_budget_Moderate         107.0986      8.959     11.954      0.000      89.539     124.658
# property_budget_High             359.2039     59.433      6.044      0.000     242.716     475.691
# property_budget_Luxury           340.5254     16.022     21.253      0.000     309.122     371.929
# ==============================================================================
# Omnibus:                   312693.196   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       6453366197.704
# Skew:                          26.577   Prob(JB):                         0.00
# Kurtosis:                    1108.022   Cond. No.                     1.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.29e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **R-Squared value obtained is Sightly Higher than the base model**

# %% [markdown]
# ## Recursive Feature Elimination

# %%
from sklearn.feature_selection import RFE
rfe=RFE(estimator=lr,n_features_to_select=29,verbose=2,importance_getter='coef_')
rfe.fit(xtrain,ytrain)
# Out:
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# RFE(estimator=LinearRegression(), importance_getter='coef_',
#     n_features_to_select=29, verbose=2)

# %%
rfe_cols=pd.DataFrame(rfe.ranking_,index=X.columns).sort_values(by=0,ascending=False)[:29].index
rfe_cols
# Out:
# Index(['property_rate', 'neighborhood_market', 'host_rank_Middle Term',
#        'host_rank_Novice', 'host_identity_verified', 'amenities_count',
#        'calculated_host_listings_count', 'host_is_superhost',
#        'availability_365', 'instant_bookable', 'neighbourhood_state_NV',
#        'neighbourhood_state_IL', 'neighbourhood_state_HI',
#        'neighbourhood_state_NY', 'neighbourhood_state_TN',
#        'neighbourhood_state_DC', 'Region_West', 'neighbourhood_state_WA',
#        'property_budget_Moderate', 'property_budget_High', 'Region_South East',
#        'Region_North East', 'neighbourhood_state_FL', 'room_type_Private room',
#        'review_category_Unknown', 'review_category_Recent',
#        'room_type_Shared room', 'room_type_Hotel room', 'amenities_score'],
#       dtype='object')

# %%
# Utilizing the features obtained from feature elimination
X2=xtrain.loc[:,rfe_cols]

# %%
newx = sma.add_constant(X2)

model_lr = sma.OLS(ytrain,newx).fit()

model_lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     751.0
# Date:                Tue, 20 Dec 2022   Prob (F-statistic):               0.00
# Time:                        22:13:47   Log-Likelihood:            -9.5591e+05
# No. Observations:              126547   AIC:                         1.912e+06
# Df Residuals:                  126520   BIC:                         1.912e+06
# Df Model:                          26
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           -154.0848     10.762    -14.318      0.000    -175.178    -132.992
# property_rate                      1.6236      0.018     89.597      0.000       1.588       1.659
# neighborhood_market                1.2859      0.022     57.910      0.000       1.242       1.329
# host_rank_Middle Term             -2.7118      4.143     -0.654      0.513     -10.833       5.409
# host_rank_Novice                   0.4218      4.458      0.095      0.925      -8.315       9.159
# host_identity_verified            -3.0104      3.322     -0.906      0.365      -9.522       3.502
# amenities_count                    8.4589      0.835     10.135      0.000       6.823      10.095
# calculated_host_listings_count   -34.9072     11.502     -3.035      0.002     -57.450     -12.364
# host_is_superhost                  0.8689      2.954      0.294      0.769      -4.921       6.659
# availability_365                  10.8357      3.546      3.056      0.002       3.885      17.786
# instant_bookable                 -15.6416      2.786     -5.615      0.000     -21.102     -10.182
# neighbourhood_state_NV           -74.7548      5.973    -12.516      0.000     -86.461     -63.049
# neighbourhood_state_IL           -32.9677      6.051     -5.449      0.000     -44.827     -21.108
# neighbourhood_state_HI           -60.2067      4.476    -13.450      0.000     -68.980     -51.433
# neighbourhood_state_NY           -17.2185      2.108     -8.167      0.000     -21.350     -13.086
# neighbourhood_state_TN           -41.4519      4.932     -8.404      0.000     -51.119     -31.785
# neighbourhood_state_DC            -0.5839      6.428     -0.091      0.928     -13.182      12.014
# Region_West                      -37.0555      4.179     -8.867      0.000     -45.246     -28.865
# neighbourhood_state_WA           -44.2742      8.216     -5.389      0.000     -60.378     -28.170
# property_budget_Moderate         -19.5693      8.966     -2.183      0.029     -37.142      -1.996
# property_budget_High             287.3941     61.755      4.654      0.000     166.356     408.433
# Region_South East                -66.8430      3.602    -18.556      0.000     -73.904     -59.783
# Region_North East                -17.2185      2.108     -8.167      0.000     -21.350     -13.086
# neighbourhood_state_FL           -25.3912      4.333     -5.860      0.000     -33.884     -16.898
# room_type_Private room            47.3220      3.638     13.009      0.000      40.193      54.451
# review_category_Unknown           84.0341     12.836      6.547      0.000      58.876     109.192
# review_category_Recent           -16.3412     12.665     -1.290      0.197     -41.164       8.482
# room_type_Shared room             68.8881     10.047      6.857      0.000      49.197      88.579
# room_type_Hotel room              86.2144     15.756      5.472      0.000      55.333     117.096
# amenities_score                  -75.1821      6.163    -12.199      0.000     -87.262     -63.103
# ==============================================================================
# Omnibus:                   303389.581   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       5006731919.746
# Skew:                          24.681   Prob(JB):                         0.00
# Kurtosis:                     976.193   Cond. No.                     1.56e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.36e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **R-Squared value obtained is lower than the base model and SFS model**

# %% [markdown]
# Inferences:
#
# 1. There is not much of a pattern with latitude and longitude but the coefficients adds value to the model.
# 2. Coefficient for No of reviews is greater than null treated reviews per month so we can remove them.
# 3. Sequential feature selection performs slightly better than RFE.

# %% [markdown]
# ### sklearn - Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

# %%
lr.fit(xtrain,ytrain)
pred_lr=lr.predict(xtest)
pred_lr_tr = lr.predict(xtrain)

# evaluation metrics
lrmodel_rmse=np.sqrt(mean_squared_error(ytest,pred_lr))
lrmodel_rmse_tr=np.sqrt(mean_squared_error(ytrain,pred_lr_tr))
lrmodel_mae=mean_absolute_error(ytest,pred_lr)
lrmodel_mae_tr=mean_absolute_error(ytrain,pred_lr_tr)
lrmodel_mape=mean_absolute_percentage_error(ytest,pred_lr)

print('train rmse:',lrmodel_rmse_tr,'\nrmse:',lrmodel_rmse,'\ntrain mae:',lrmodel_mae_tr,'\nmae:',lrmodel_mae,'\nmape:',lrmodel_mape)
# Out:
# train rmse: 444.15444854950164
# rmse: 468.0071743198311
# train mae: 121.41566442297331
# mae: 120.30779639773749
# mape: 0.8101777440238896

# %% [markdown]
# ## Robust Models
# Note: Median is robust to outliers, hence MAE is a better metric for Huber than mean

# %% [markdown]
# ### Huber Regression

# %%
from sklearn.linear_model import HuberRegressor

huber=HuberRegressor()
huber.fit(xtrain,ytrain)
huber_pred_tr=huber.predict(xtrain)
huber_pred=huber.predict(xtest)

# %%
# huber = HuberRegressor().fit(X, y)
# fit_df["huber_regression"] = huber.predict(plotline_X)
# coef_list.append(["huber_regression", huber.coef_[0]])

# %%
np.sqrt(mean_squared_error(ytrain,huber_pred_tr)),np.sqrt(mean_squared_error(ytest,huber_pred))
# Out:
# (470.2860059759556, 492.55192453643764)

# %%
mean_absolute_error(ytrain,huber_pred_tr),mean_absolute_error(ytest,huber_pred)
# Out:
# (100.36766585353729, 99.22768771236613)

# %%
mean_absolute_percentage_error(ytest,huber_pred)
# Out:
# 0.4355034085091587

# %% [markdown]
# ### RANSAC method

# %%
from sklearn.linear_model import RANSACRegressor

ransac=RANSACRegressor(base_estimator=lr,random_state=42)

ransac.fit(xtrain,ytrain)
ransac_pred_tr=ransac.predict(xtrain)
ransac_pred=ransac.predict(xtest)

# %%
np.sqrt(mean_squared_error(ytrain,ransac_pred_tr)),np.sqrt(mean_squared_error(ytest,ransac_pred))
# Out:
# (119289.48208562836, 512.5875784982765)

# %%
mean_absolute_error(ytrain,ransac_pred_tr),mean_absolute_error(ytest,ransac_pred)
# Out:
# (556.9836968582539, 121.40960968370996)

# %%
mean_absolute_percentage_error(ytest,ransac_pred)
# Out:
# 0.6060338123778906

# %% [markdown]
# ### Theil-Sen Regression

# %%
from sklearn.linear_model import TheilSenRegressor

ts=TheilSenRegressor(random_state=42)
ts.fit(xtrain,ytrain)
ts_pred_tr=ts.predict(xtrain)
ts_pred=ts.predict(xtest)

# %%
np.sqrt(mean_squared_error(ytrain,ts_pred_tr)),np.sqrt(mean_squared_error(ytest,ts_pred))
# Out:
# (118332.62889096647, 854.4091068131312)

# %%
mean_absolute_error(ytrain,ts_pred_tr),mean_absolute_error(ytest,ts_pred)
# Out:
# (617.2856745603551, 279.7428692800363)

# %%
mean_absolute_percentage_error(ytest,ts_pred)
# Out:
# 2.699529815492625

# %%
linear_models=pd.DataFrame()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

dt=DecisionTreeRegressor(random_state=42)

dtmodel=dt.fit(xtrain,ytrain)
dtpred_tr=dtmodel.predict(xtrain)
dtpred=dtmodel.predict(xtest)

# %%
np.sqrt(mean_squared_error(ytrain,dtpred_tr)),np.sqrt(mean_squared_error(ytest,dtpred))
# Out:
# (1.3871407477139936, 579.9080986770153)

# %%
mean_absolute_error(ytrain,dtpred_tr),mean_absolute_error(ytest,dtpred)
# Out:
# (0.06176089963141415, 110.160610773383)

# %%
mean_absolute_percentage_error(ytest,dtpred)
# Out:
# 0.5516596602315438

# %% [markdown]
# ## Regularization Models

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %% [markdown]
# ## Ridge

# %%
ridge=Ridge(normalize=True)
ridge.fit(xtrain,ytrain)
rid_pred=ridge.predict(xtest)
rid_pred_tr=ridge.predict(xtrain)

# %%
np.sqrt(mean_squared_error(ytrain,rid_pred_tr)),np.sqrt(mean_squared_error(ytest,rid_pred))
# Out:
# (450.0813118904755, 473.28846768682286)

# %%
mean_absolute_error(ytrain,rid_pred_tr),mean_absolute_error(ytest,rid_pred)
# Out:
# (108.7810396195631, 108.1054292867201)

# %%
mean_absolute_percentage_error(ytest,rid_pred)
# Out:
# 0.6758427462054944

# %% [markdown]
# ## Lasso

# %%
lasso=Lasso(normalize=True)
lasso.fit(xtrain,ytrain)
las_pred=lasso.predict(xtest)
las_pred_tr=lasso.predict(xtrain)

# %%
np.sqrt(mean_squared_error(ytrain,las_pred_tr)),np.sqrt(mean_squared_error(ytest,las_pred))
# Out:
# (496.0346907839338, 516.6984726042349)

# %%
mean_absolute_error(ytrain,las_pred_tr),mean_absolute_error(ytest,las_pred)
# Out:
# (154.4089497688718, 153.0571309319713)

# %%
mean_absolute_percentage_error(ytest,las_pred)
# Out:
# 1.3012328088625165

# %% [markdown]
# ## Elastic Net

# %%
enet=ElasticNet(normalize=True)
enet.fit(xtrain,ytrain)
enet_pred=enet.predict(xtest)
enet_pred_tr=enet.predict(xtrain)

# %%
np.sqrt(mean_squared_error(ytrain,enet_pred_tr)),np.sqrt(mean_squared_error(ytest,enet_pred))
# Out:
# (496.0346907839338, 516.6984726042349)

# %%
mean_absolute_error(ytrain,enet_pred_tr),mean_absolute_error(ytest,enet_pred)
# Out:
# (154.4089497688718, 153.0571309319713)

# %%
mean_absolute_percentage_error(ytest,enet_pred)
# Out:
# 1.3012328088625165

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor()
rf.fit(xtrain,ytrain)
pred_rf_tr=rf.predict(xtrain)
pred_rf=rf.predict(xtest)

# %%
np.sqrt(mean_squared_error(ytrain,pred_rf_tr)),np.sqrt(mean_squared_error(ytest,pred_rf))
# Out:
# (151.08598511328267, 431.58797468897217)

# %%
mean_absolute_error(ytrain,pred_rf_tr),mean_absolute_error(ytest,pred_rf)
# Out:
# (32.39190031258716, 84.66455364702276)

# %%
mean_absolute_percentage_error(ytest,pred_rf)
# Out:
# 0.4600346491916129

# %% [markdown]
# ## Bagging

# %%
from sklearn.ensemble import BaggingRegressor

br=BaggingRegressor(bootstrap=True)
br.fit(xtrain,ytrain)
br_pred=br.predict(xtest)
br_pred_tr=br.predict(xtrain)

# %%
np.sqrt(mean_squared_error(ytrain,br_pred_tr)),np.sqrt(mean_squared_error(ytest,br_pred))
# Out:
# (175.54031544120565, 452.63252950552214)

# %%
mean_absolute_error(ytrain,br_pred_tr),mean_absolute_error(ytest,br_pred)
# Out:
# (36.39182317358208, 91.28115721302987)

# %%
mean_absolute_percentage_error(ytest,br_pred)
# Out:
# 0.492409300413484

# %% [markdown]
# ## Boosting

# %% [markdown]
# ### Ada Boost

# %%
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor()
ada.fit(xtrain,ytrain)
ada_pred=ada.predict(xtest)
ada_pred_tr=ada.predict(xtrain)

# %%
np.sqrt(mean_squared_error(ytrain,ada_pred_tr)),np.sqrt(mean_squared_error(ytest,ada_pred))
# Out:
# (834.7271203986184, 858.9451689104818)

# %%
mean_absolute_error(ytrain,ada_pred_tr),mean_absolute_error(ytest,ada_pred)
# Out:
# (677.542773791356, 678.7905151980344)

# %%
mean_absolute_percentage_error(ytest,ada_pred)
# Out:
# 7.528557586875422

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(xtrain,ytrain)
gbr_pred=ada.predict(xtest)
gbr_pred_tr=ada.predict(xtrain)

# %%
np.sqrt(mean_squared_error(ytrain,gbr_pred_tr)),np.sqrt(mean_squared_error(ytest,gbr_pred))
# Out:
# (834.7271203986184, 858.9451689104818)

# %%
mean_absolute_error(ytrain,gbr_pred_tr),mean_absolute_error(ytest,gbr_pred)
# Out:
# (677.542773791356, 678.7905151980344)

# %%
mean_absolute_percentage_error(ytest,gbr_pred)
# Out:
# 7.528557586875422

# %%
# !pip install xgboost

# %% [markdown]
# ### XG Boost

# %%
from xgboost import XGBRegressor
xgbr=XGBRegressor()
xgbr.fit(xtrain,ytrain)
pred_xbgr=xgbr.predict(xtest)
pred_xbgr_tr=xgbr.predict(xtrain)

# %%
np.sqrt(mean_squared_error(ytrain,pred_xbgr_tr)),np.sqrt(mean_squared_error(ytest,pred_xbgr))
# Out:
# (206.68015237647856, 399.131945908214)

# %%
mean_absolute_error(ytrain,pred_xbgr_tr),mean_absolute_error(ytest,pred_xbgr)
# Out:
# (71.36463221402718, 88.54466556274839)

# %%
mean_absolute_percentage_error(ytest,pred_xbgr)
# Out:
# 0.5036551940775625

# %% [markdown]
# ## Stacking Model

# %%
from sklearn.ensemble import StackingRegressor

huber=HuberRegressor()
rf=RandomForestRegressor()
xgbr=XGBRegressor()

base=[('huber',huber),('rf',rf),('xgbr',xgbr)]
final=rf

# %%
stack=StackingRegressor(estimators=base, final_estimator=final)
stack.fit(xtrain,ytrain)
pred_stack=stack.predict(xtest)
pred_stack_tr=stack.predict(xtrain)

# %%
np.sqrt(mean_squared_error(ytrain,pred_stack_tr)),np.sqrt(mean_squared_error(ytest,pred_stack))
# Out:
# (241.15148907749204, 401.6337175758733)

# %%
mean_absolute_error(ytrain,pred_stack_tr),mean_absolute_error(ytest,pred_stack)
# Out:
# (58.5732191597241, 87.31359507625794)

# %%
mean_absolute_percentage_error(ytest,pred_stack)
# Out:
# 0.46945118854431667

# %% [markdown]
# ## Parameter Tuning - Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
## Parameter Tuning 


from sklearn.model_selection import GridSearchCV
rf = RandomForestRegressor()
param_grid={
    'n_estimators':[100,200,300],
    'min_samples_leaf':range(1,5,1),
    'min_samples_split':range(2,10,2),
    'max_depth':[2,3,4,None],
    'max_features':[0.2]
}

cv=GridSearchCV(estimator=rf,param_grid=param_grid,cv=3,verbose=1,scoring='neg_mean_absolute_error')
cv.fit(xtrain,ytrain)
cv.best_params_
# Out:
# Fitting 3 folds for each of 192 candidates, totalling 576 fits
# {'max_depth': None,
#  'max_features': 0.2,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
from sklearn.ensemble import RandomForestRegressor

rf_tuned=RandomForestRegressor(n_estimators=300,min_samples_leaf=1,min_samples_split=2,
                         max_features=0.2,random_state=0)
rf_tuned.fit(xtrain,ytrain)
pred_rf_tuned_tr=rf_tuned.predict(xtrain)
pred_rf_tuned_te=rf_tuned.predict(xtest)

# %%
np.sqrt(mean_squared_error(ytrain,pred_rf_tuned_tr)),np.sqrt(mean_squared_error(ytest,pred_rf_tuned_te))
# Out:
# (138.68355314440763, 411.6864613604141)

# %%
mean_absolute_error(ytrain,pred_rf_tuned_tr),mean_absolute_error(ytest,pred_rf_tuned_te)
# Out:
# (30.31573390875489, 80.9384117945001)

# %%
mean_absolute_error(ytrain,pred_rf_tuned_tr),mean_absolute_error(ytest,pred_rf_tuned_te)
# Out:
# (30.31573390875489, 80.9384117945001)

# %%
models=pd.DataFrame()
models['Model']=['Huber Regression','RANSAC Regression','Theil-Sen Regression',
                 'Linear Regression','Decision Tree','Random Forest','Bagging',
                 'AdaBoost','Gradient Boosting','XGBoost','Stacking Model',
                 'Random Forest Tuned','Ridge','Lasso','Elastic Net']

models['RMSE']=[np.sqrt(mean_squared_error(ytest,huber_pred)),np.sqrt(mean_squared_error(ytest,ransac_pred)),
                    np.sqrt(mean_squared_error(ytest,ts_pred)),np.sqrt(mean_squared_error(ytest,pred_lr)),
                    np.sqrt(mean_squared_error(ytest,dtpred)),np.sqrt(mean_squared_error(ytest,pred_rf)),
                    np.sqrt(mean_squared_error(ytest,br_pred)),np.sqrt(mean_squared_error(ytest,ada_pred)),
                    np.sqrt(mean_squared_error(ytest,gbr_pred)),np.sqrt(mean_squared_error(ytest,pred_xbgr)),
                    np.sqrt(mean_squared_error(ytest,pred_stack)),np.sqrt(mean_squared_error(ytest,pred_rf_tuned_te)),
                    np.sqrt(mean_squared_error(ytest,rid_pred)) , np.sqrt(mean_squared_error(ytest,las_pred)),
                    np.sqrt(mean_squared_error(ytest,enet_pred))]


models['MAE']=[mean_absolute_error(ytest,huber_pred),mean_absolute_error(ytest,ransac_pred),
                    mean_absolute_error(ytest,ts_pred),mean_absolute_error(ytest,pred_lr),
                    mean_absolute_error(ytest,dtpred),mean_absolute_error(ytest,pred_rf),
                    mean_absolute_error(ytest,br_pred),mean_absolute_error(ytest,ada_pred),
                    mean_absolute_error(ytest,gbr_pred),mean_absolute_error(ytest,pred_xbgr),
                    mean_absolute_error(ytest,pred_stack),mean_absolute_error(ytest,pred_rf_tuned_te),
                    mean_absolute_error(ytest,rid_pred),mean_absolute_error(ytest,las_pred),
                    mean_absolute_error(ytest,enet_pred)]

models['MAPE']=[mean_absolute_percentage_error(ytest,huber_pred),mean_absolute_percentage_error(ytest,ransac_pred),
                    mean_absolute_percentage_error(ytest,ts_pred),mean_absolute_percentage_error(ytest,pred_lr),
                    mean_absolute_percentage_error(ytest,dtpred),mean_absolute_percentage_error(ytest,pred_rf),
                    mean_absolute_percentage_error(ytest,br_pred),mean_absolute_percentage_error(ytest,ada_pred),
                    mean_absolute_percentage_error(ytest,gbr_pred),mean_absolute_percentage_error(ytest,pred_xbgr),
                    mean_absolute_percentage_error(ytest,pred_stack),mean_absolute_percentage_error(ytest,pred_rf_tuned_te),
                    mean_absolute_percentage_error(ytest,rid_pred),mean_absolute_percentage_error(ytest,las_pred),
                    mean_absolute_percentage_error(ytest,enet_pred)]
models.sort_values(by='MAPE',ascending=True)
# Out:
#                    Model        RMSE         MAE      MAPE
# 0       Huber Regression  492.551925   99.227688  0.435503
# 11   Random Forest Tuned  411.686461   80.938412  0.442968
# 5          Random Forest  431.587975   84.664554  0.460035
# 10        Stacking Model  401.633718   87.313595  0.469451
# 6                Bagging  452.632530   91.281157  0.492409
# 9                XGBoost  399.131946   88.544666  0.503655
# 4          Decision Tree  579.908099  110.160611  0.551660
# 1      RANSAC Regression  512.587578  121.409610  0.606034
# 12                 Ridge  473.288468  108.105429  0.675843
# 3      Linear Regression  468.007174  120.307796  0.810178
# 13                 Lasso  516.698473  153.057131  1.301233
# 14           Elastic Net  516.698473  153.057131  1.301233
# 2   Theil-Sen Regression  854.409107  279.742869  2.699530
# 7               AdaBoost  858.945169  678.790515  7.528558
# 8      Gradient Boosting  858.945169  678.790515  7.528558

# %% [markdown]
# ## Inference
# * A total of 15 base models are built for prediction.
# * Since we tend to proceed model building with outliers we prioritize the metrics MAE and MAPE.
# * The reason is because MAE and MAPE deal with the median score which is robust to outliers compared to RMSE which is sensitive to them.
# * The top three models on infering the MAE and MAPE score are Random forest regression model, Stacking regression model and Huber regression Model.
# * Out of these three we found Random forest model to be promising and providing a generalized and ideal MAPE value 0.45 approx.
# * On tuning the Random forest model through GridSearchCV we rebuild and find the MAPE value to be 0.43 approx which shows a minute improvement.

# %% [markdown]
# # Model deployment

# %%
def preprocessing(final_df):
    X = final_df.drop('price', axis = 1)
    y = final_df['price']
    x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.3, random_state = 0)
    return x_train, x_test, y_train, y_test

# %%
#create api pipeline for deployment

from sklearn.pipeline import Pipeline
steps=[('Huber',huber)]
pipeline=Pipeline(steps)
x_train,x_test,y_train,y_test=preprocessing(final_df)
ypred=pipeline.fit(x_train,y_train).predict(x_test)
print('RMSE of pipeline',np.sqrt(mean_squared_error(y_test,ypred)))
print('MAE of pipeline',mean_absolute_error(y_test,ypred))
print('MAPE of pipeline',mean_absolute_percentage_error(y_test,ypred))
# Out:
# RMSE of pipeline 473.54534906996815
# MAE of pipeline 100.75353043221705
# MAPE of pipeline 0.43619488968790743

# %%
## Save the pipeline as a Pickle File

import pickle
model = open('airbnb.pickle', 'wb')
pickle.dump(pipeline, model)
model.close()

# %%
pickle_model=pickle.load(open('airbnb.pickle','rb'))

# %%
pickle_model.predict(x_test)
# Out:
# array([ 88.42494264, 124.65166467, 100.82069076, ...,  58.00233391,
#         84.20822956, 135.12599554])

# %%
# %%writefile app1.py
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import pickle
st.title('Host Optimal Price Prediction')

# Load Model

rf_model=pickle.load(open('airbnb.pickle','rb'))


# Create UI
host_is_superhost=st.selectbox('A superhost?',(0,1))
host_identity_verified=st.selectbox('Host verified?',(0,1))
instant_bookable=st.selectbox('Instantly Bookable',(0,1))
accommodates=st.selectbox('Number of accomodates',{6:0.375, 1:0.0625, 2:0.125 ,3:0.1875, 4:0.25,5: 0.3125, 8:0.5 ,7: 0.4375,
                                                      10:0.625 , 15:0.9375,12: 0.75 , 16:1.,9: 0.5625, 14:0.875 ,11: 0.6875,
                                                       13:0.8125,0:0.})
bathrooms=st.selectbox('Number of bathrooms',{2.:0.04,1.5:0.03,1.: 0.02,2.5:0.05,3.5:0.07,11.:0.22,3.:0.06,6.5:0.13,4.:0.08,
                                                  8.: 0.16,8.5: 0.17,0.:0.  ,4.5: 0.09,7.5: 0.15,5.: 0.1 ,0.5: 0.01,11.5: 0.23,
                                                  5.5: 0.11,6.:0.12,7.:0.14,9.: 0.18,12.5: 0.25,10.:0.2 ,12.: 0.24,13.:0.26,
                                                  9.5: 0.19,10.5: 0.21,25.:0.5 ,27.5:0.55,42.: 0.84, 20:0.4 ,14.: 0.28,13.5: 0.27,
                                                   17.:0.34,15.5: 0.31,19.:0.38,16.: 0.32,15.:0.3 ,50.:1.})
bedrooms=st.selectbox('Number of bedrooms',{2.:0.04,1.:0.02,3.:0.06,4.:0.08,6.:0.12,5.:0.1 ,7.:0.14,9.:0.18,8.:0.16,11.:0.22,12.:0.24,
                                               10.:0.2,13.:0.26,50:1.,21.:0.42,14.:0.28,0.:0.,17.:0.34,16.:0.32,22.:0.44,15.:0.3 ,18.:0.36,
                                               37.:0.74,27:0.54})
beds=st.selectbox('Number of beds',{3.:0.04545455,1.: 0.01515152, 2.:0.03030303,0.: 0.,4.: 0.06060606,
                                       5.:0.07575758,6.: 0.09090909,9.:0.13636364,7.: 0.10606061,8.: 0.12121212,
                                       11.:0.16666667,15.: 0.22727273,10.: 0.15151515,14.: 0.21212121,16.: 0.24242424,
                                       12.:0.18181818,19.: 0.28787879,13.: 0.1969697 ,50.: 0.75757576,22.: 0.33333333,
                                       32.:0.48484848,18.: 0.27272727,21.: 0.31818182,20.: 0.3030303 ,23.: 0.34848485,
                                       44.:0.66666667,17.: 0.25757576,26.: 0.39393939,54.: 0.81818182,38.: 0.57575758,
                                       25.:0.37878788, 30.:0.45454545,42.: 0.63636364,24.: 0.36363636,33.:0.5,
                                       27.:0.40909091, 31.:0.46969697, 40.:0.60606061,29.: 0.43939394,66.: 1.,
                                       55.: 0.83333333, 46.:0.6969697 ,51.: 0.77272727})
minimum_nights=st.selectbox('Minimum number of nights',{30:2.90000003e-07,1:0.00000000e+00, 2:1.00000001e-08, 31:3.00000003e-07,
                                                         3:2.00000002e-08,5: 4.00000004e-08,4: 3.00000003e-08,32:3.10000003e-07,
                                                         7:6.00000006e-08,180:1.79000002e-06})
maximum_nights=st.selectbox('Maximum number of nights',{730:3.39932740e-07, 366:1.70432031e-07,180: 8.38190318e-08,1125: 5.23868948e-07,
                                                         90:4.19095159e-08,7: 3.25962901e-09,365: 1.69966370e-07,150: 6.98491931e-08,
                                                         120:5.58793545e-08, 60:2.79396773e-08})
number_of_reviews=st.selectbox('Reviews count',{2:1.09589041e-03,27:1.47945205e-02, 21:1.15068493e-02, 0:0.00000000e+00,
                                                 310:1.69863014e-01,230:1.26027397e-01,128:7.01369863e-02,22: 1.20547945e-02,
                                                 12:6.57534247e-03,241: 1.32054795e-01})
availability_365=st.selectbox('Days of availability',{216:0.59178082,360: 0.98630137, 337:0.92328767,0: 0.,332: 0.90958904,
                                                        154:0.42191781,329: 0.90136986, 119:0.3260274 ,49: 0.13424658,349:0.95068493})
amenities_count=st.selectbox('Number of amenities',[13, 17, 11, 10,  9, 16, 18,  5,  7, 14, 15,  8, 12,  6,  4,  3,  0,
                                                    2, 20, 19, 21,  1, 22, 23, 24])

# User to model input

data={'A superhost?':host_is_superhost,
     'Host verified?':host_identity_verified,
     'Instantly Bookable':instant_bookable,
     'Number of accomodates':accommodates,
     'latitude':22.0515,
     'longitude':-159.33409,
     'Number of bathrooms':bathrooms,
     'Number of bedrooms':bedrooms,
     'Number of beds':beds,
     'Minimum number of nights':minimum_nights,
     'Maximum number of nights':maximum_nights,
     'Reviews count':number_of_reviews,
     'calculated_host_listings_count':0.01298701, 
     'Days of availability':availability_365,
     'host_months':0.92253521,
     'amenities_score':1.89859016,
     'Number of amenities':amenities_count,
     'neighborhood_market':118.,'property_rate':173.,
     'room_type_Hotel room':1, 'room_type_Private room':0,
     'room_type_Shared room':0, 'review_category_Recent':1,
     'review_category_Unknown':0, 'host_rank_Middle Term':0, 'host_rank_Novice':0,
     'Region_North East':0, 'Region_South East':1, 'Region_West':0,
     'neighbourhood_state_DC':0, 'neighbourhood_state_FL':1,
     'neighbourhood_state_HI':0, 'neighbourhood_state_IL':0,
     'neighbourhood_state_NV':0, 'neighbourhood_state_NY':0,
     'neighbourhood_state_TN':0, 'neighbourhood_state_WA':0,
     'property_budget_Moderate':1, 'property_budget_High':0,
     'property_budget_Luxury':0}

in_data=pd.DataFrame([data])
predictions=rf_model.predict(in_data)[0]

if st.button('Predict'):
    st.write(predictions)

st.subheader('Host Price')
# Out:
# Overwriting app1.py
